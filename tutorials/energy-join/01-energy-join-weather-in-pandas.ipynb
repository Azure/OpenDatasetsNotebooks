# %% [markdown]
# # Load nyc_energy and enrich it with weather data
#
# In this notebook, we try to enrich the NYC Energy data in Jupyter Notebook in a scalable way.
# We enrich the input data by month, put the monthly enriched data in the temp folder, and save the final result in the current folder every time we have done one month.
#
# * Load csv file which is downloaded from:  https://notebooks.azure.com/frlazzeri/projects/automatedml-ms-build/html/nyc_energy.csv
# * Time range: 1/1/2012  to 8/12/2017
# * Location: 'PORT AUTH DOWNTN MANHATTAN WALL ST' station at <font color='red'>lat: 40.701, long: -74.009</font>

# %%
# install packages if it's not availble.

# !pip uninstall -y azureml-contrib-opendatasets
# !pip install azureml-contrib-opendatasets

# %% [markdown]
# ### Initialize global variables.

# %%
from datetime import datetime


start_date = datetime(2012, 1, 1, 0, 0)
end_date = datetime(2017, 8, 12, 23, 59)

start_date, end_date
# Out:
# (datetime.datetime(2012, 1, 1, 0, 0), datetime.datetime(2017, 8, 12, 23, 59))

# %%
from datetime import timedelta
from dateutil.relativedelta import relativedelta

import math


r = relativedelta(end_date, start_date)
months = r.years * 12 + r.months + math.floor((r.days + 30)/31)
months
# Out:
# 68

# %%
lat, long = 40.701, -74.009
lat, long
# Out:
# (40.701, -74.009)

# %% [markdown]
# ### Load ``"./nyc_energy.csv"`` (download and save to local) and preview the data.

# %%
from pandas import read_csv


df = read_csv('./nyc_energy.csv').drop(columns=['precip', 'temp'], axis=1)
df['lat'] = lat
df['long'] = long
df.head(5)
# Out:
#              timeStamp  demand     lat    long
# 0  2012-01-01 00:00:00  4937.5  40.701 -74.009
# 1  2012-01-01 01:00:00  4752.1  40.701 -74.009
# 2  2012-01-01 02:00:00  4542.6  40.701 -74.009
# 3  2012-01-01 03:00:00  4357.7  40.701 -74.009
# 4  2012-01-01 04:00:00  4275.5  40.701 -74.009

# %% [markdown]
# ### Extend the timeStamp column so that we can filter it easily.

# %%
from dateutil import parser


df['datetime'] = df['timeStamp'].apply(parser.parse)
df.head(5)
# Out:
#              timeStamp  demand     lat    long            datetime
# 0  2012-01-01 00:00:00  4937.5  40.701 -74.009 2012-01-01 00:00:00
# 1  2012-01-01 01:00:00  4752.1  40.701 -74.009 2012-01-01 01:00:00
# 2  2012-01-01 02:00:00  4542.6  40.701 -74.009 2012-01-01 02:00:00
# 3  2012-01-01 03:00:00  4357.7  40.701 -74.009 2012-01-01 03:00:00
# 4  2012-01-01 04:00:00  4275.5  40.701 -74.009 2012-01-01 04:00:00

# %% [markdown]
# ### Create the temp folder in which we save the enriched data per month.

# %%
# !if [ ! -d "./temp" ]; then mkdir temp; fi

# %%
import os.path
import pandas as pd
from azureml.contrib.opendatasets.accessories.location_data import LatLongColumn
from azureml.contrib.opendatasets.accessories.location_time_customer_data \
    import LocationTimeCustomerData
from azureml.contrib.opendatasets import NoaaIsdWeather


if os.path.exists('./nyc_energy_enriched.csv'):
    print('nyc_energy_enriched.csv exists already.')
else:
    print('[%s] Start enriching...' % datetime.now())
    all = pd.DataFrame([])
    i_date = start_date
    for m in range(months):
        j_date = i_date + relativedelta(months=1) - timedelta(milliseconds=1)

        # This is important to set monotonically increasing index for successful enrichemnt.
        df1 = df[(df['datetime'] >= i_date) & (df['datetime'] <= j_date)]
        df1['idx'] = list(range(len(df1.index)))
        df1 = df1.set_index('idx')

        energy = LocationTimeCustomerData(
            df1,
            LatLongColumn('lat', 'long'),
            'datetime')

        weather = NoaaIsdWeather(
            cols=["temperature", "precipTime", "precipDepth", "snowDepth"],
            start_date=i_date,
            end_date=j_date)

        weather_enricher = weather.get_enricher()
        joined_data = weather_enricher.enrich_customer_data_with_agg(
            customer_data_object=energy,
            location_match_granularity=5, # higher for high join success rate, lower for performance.
            time_round_granularity='day',
            agg='avg')

        fn = './temp/nyc_energy_enriched_%s.csv' % i_date
        joined_data.data.to_csv(fn)

        all = pd.concat([all, joined_data.data])
        all.to_csv('./nyc_energy_enriched.csv')

        i_date += relativedelta(months=1)

    print('[%s] End enriching...' % datetime.now())
# Out:
# [2019-04-26 06:43:47.660633] Start enriching...
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# ActivityStarted, get_enricher
# ActivityCompleted: Activity=get_enricher, HowEnded=Success, Duration=20.84 [ms]
# ActivityStarted, enrich_customer_data_with_agg
# ActivityStarted, enrich
# Target paths: ['/year=2012/month=1/']
# Looking for parquet files...
# Reading them into Pandas dataframe...
# Reading ISDWeather/year=2012/month=1/part-00004-tid-7816671341480880202-0b49e80b-f206-4731-ab5a-61d53f99b595-57.c000.snappy.parquet under container isdweatherdatacontainer
# Done.
# ActivityCompleted: Activity=enrich, HowEnded=Success, Duration=126889.75 [ms]
# ActivityCompleted: Activity=enrich_customer_data_with_agg, HowEnded=Success, Duration=126911.75 [ms]
# ActivityStarted, get_enricher
# ActivityCompleted: Activity=get_enricher, HowEnded=Success, Duration=3.39 [ms]
# ActivityStarted, enrich_customer_data_with_agg
# ActivityStarted, enrich
# Target paths: ['/year=2012/month=2/']
# Looking for parquet files...
# Reading them into Pandas dataframe...
# Reading ISDWeather/year=2012/month=2/part-00011-tid-7816671341480880202-0b49e80b-f206-4731-ab5a-61d53f99b595-64.c000.snappy.parquet under container isdweatherdatacontainer
# Done.
# ActivityCompleted: Activity=enrich, HowEnded=Success, Duration=42102.48 [ms]
# ActivityCompleted: Activity=enrich_customer_data_with_agg, HowEnded=Success, Duration=42108.5 [ms]
# ActivityStarted, get_enricher
# ActivityCompleted: Activity=get_enricher, HowEnded=Success, Duration=3.86 [ms]
# ActivityStarted, enrich_customer_data_with_agg
# ActivityStarted, enrich
# Target paths: ['/year=2012/month=3/']
# Looking for parquet files...
# Reading them into Pandas dataframe...
# Reading ISDWeather/year=2012/month=3/part-00001-tid-7816671341480880202-0b49e80b-f206-4731-ab5a-61d53f99b595-54.c000.snappy.parquet under container isdweatherdatacontainer
# Done.
# ActivityCompleted: Activity=enrich, HowEnded=Success, Duration=43003.45 [ms]
# ActivityCompleted: Activity=enrich_customer_data_with_agg, HowEnded=Success, Duration=43010.18 [ms]
# ActivityStarted, get_enricher
# ActivityCompleted: Activity=get_enricher, HowEnded=Success, Duration=3.81 [ms]
# ActivityStarted, enrich_customer_data_with_agg
# ActivityStarted, enrich
# Target paths: ['/year=2012/month=4/']
# Looking for parquet files...
# Reading them into Pandas dataframe...
# Reading ISDWeather/year=2012/month=4/part-00005-tid-7816671341480880202-0b49e80b-f206-4731-ab5a-61d53f99b595-58.c000.snappy.parquet under container isdweatherdatacontainer
# Done.
# ActivityCompleted: Activity=enrich, HowEnded=Success, Duration=41109.33 [ms]
# ActivityCompleted: Activity=enrich_customer_data_with_agg, HowEnded=Success, Duration=41127.07 [ms]
# ActivityStarted, get_enricher
# ActivityCompleted: Activity=get_enricher, HowEnded=Success, Duration=2.88 [ms]
# ActivityStarted, enrich_customer_data_with_agg
# ActivityStarted, enrich
# Target paths: ['/year=2012/month=5/']
# Looking for parquet files...
# Reading them into Pandas dataframe...
# Reading ISDWeather/year=2012/month=5/part-00003-tid-7816671341480880202-0b49e80b-f206-4731-ab5a-61d53f99b595-56.c000.snappy.parquet under container isdweatherdatacontainer
# Done.
# ActivityCompleted: Activity=enrich, HowEnded=Success, Duration=45190.34 [ms]
# ActivityCompleted: Activity=enrich_customer_data_with_agg, HowEnded=Success, Duration=45223.03 [ms]
# ActivityStarted, get_enricher
# ActivityCompleted: Activity=get_enricher, HowEnded=Success, Duration=2.77 [ms]
# ActivityStarted, enrich_customer_data_with_agg
# ActivityStarted, enrich
# Target paths: ['/year=2012/month=6/']
# Looking for parquet files...
# Reading them into Pandas dataframe...
# Reading ISDWeather/year=2012/month=6/part-00010-tid-7816671341480880202-0b49e80b-f206-4731-ab5a-61d53f99b595-63.c000.snappy.parquet under container isdweatherdatacontainer
# Done.
# ActivityCompleted: Activity=enrich, HowEnded=Success, Duration=40517.68 [ms]
# ActivityCompleted: Activity=enrich_customer_data_with_agg, HowEnded=Success, Duration=40550.76 [ms]
# ActivityStarted, get_enricher
# ActivityCompleted: Activity=get_enricher, HowEnded=Success, Duration=2.05 [ms]
# ActivityStarted, enrich_customer_data_with_agg
# ActivityStarted, enrich
# Target paths: ['/year=2012/month=7/']
# Looking for parquet files...
# Reading them into Pandas dataframe...
# Reading ISDWeather/year=2012/month=7/part-00006-tid-7816671341480880202-0b49e80b-f206-4731-ab5a-61d53f99b595-59.c000.snappy.parquet under container isdweatherdatacontainer
# Done.
# ActivityCompleted: Activity=enrich, HowEnded=Success, Duration=43987.11 [ms]
# ActivityCompleted: Activity=enrich_customer_data_with_agg, HowEnded=Success, Duration=43993.31 [ms]
# ActivityStarted, get_enricher
# ActivityCompleted: Activity=get_enricher, HowEnded=Success, Duration=3.89 [ms]
# ActivityStarted, enrich_customer_data_with_agg
# ActivityStarted, enrich
# Target paths: ['/year=2012/month=8/']
# Looking for parquet files...
# Reading them into Pandas dataframe...
# Reading ISDWeather/year=2012/month=8/part-00007-tid-7816671341480880202-0b49e80b-f206-4731-ab5a-61d53f99b595-60.c000.snappy.parquet under container isdweatherdatacontainer
# Done.
# ActivityCompleted: Activity=enrich, HowEnded=Success, Duration=56079.22 [ms]
# ActivityCompleted: Activity=enrich_customer_data_with_agg, HowEnded=Success, Duration=56093.66 [ms]
# ActivityStarted, get_enricher
# ActivityCompleted: Activity=get_enricher, HowEnded=Success, Duration=3.14 [ms]
# ActivityStarted, enrich_customer_data_with_agg
# ActivityStarted, enrich
# Target paths: ['/year=2012/month=9/']
# Looking for parquet files...
# Reading them into Pandas dataframe...
# Reading ISDWeather/year=2012/month=9/part-00008-tid-7816671341480880202-0b49e80b-f206-4731-ab5a-61d53f99b595-61.c000.snappy.parquet under container isdweatherdatacontainer
# Done.
# ActivityCompleted: Activity=enrich, HowEnded=Success, Duration=42161.36 [ms]
# ActivityCompleted: Activity=enrich_customer_data_with_agg, HowEnded=Success, Duration=42179.59 [ms]
# ActivityStarted, get_enricher
# ActivityCompleted: Activity=get_enricher, HowEnded=Success, Duration=3.43 [ms]
# ActivityStarted, enrich_customer_data_with_agg
# ActivityStarted, enrich
# Target paths: ['/year=2012/month=10/']
# Looking for parquet files...
# Reading them into Pandas dataframe...
# Reading ISDWeather/year=2012/month=10/part-00002-tid-7816671341480880202-0b49e80b-f206-4731-ab5a-61d53f99b595-55.c000.snappy.parquet under container isdweatherdatacontainer
# Done.
# ActivityCompleted: Activity=enrich, HowEnded=Success, Duration=41015.63 [ms]
# ActivityCompleted: Activity=enrich_customer_data_with_agg, HowEnded=Success, Duration=41029.18 [ms]
# ActivityStarted, get_enricher
# ActivityCompleted: Activity=get_enricher, HowEnded=Success, Duration=3.88 [ms]
# ActivityStarted, enrich_customer_data_with_agg
# ActivityStarted, enrich
# Target paths: ['/year=2012/month=11/']
# Looking for parquet files...
# Reading them into Pandas dataframe...
# Reading ISDWeather/year=2012/month=11/part-00009-tid-7816671341480880202-0b49e80b-f206-4731-ab5a-61d53f99b595-62.c000.snappy.parquet under container isdweatherdatacontainer
# Done.
# ActivityCompleted: Activity=enrich, HowEnded=Success, Duration=42430.49 [ms]
# ActivityCompleted: Activity=enrich_customer_data_with_agg, HowEnded=Success, Duration=42441.82 [ms]
# ActivityStarted, get_enricher
# ActivityCompleted: Activity=get_enricher, HowEnded=Success, Duration=3.95 [ms]
# ActivityStarted, enrich_customer_data_with_agg
# ActivityStarted, enrich
# Target paths: ['/year=2012/month=12/']
# Looking for parquet files...
# Reading them into Pandas dataframe...
# Reading ISDWeather/year=2012/month=12/part-00000-tid-7816671341480880202-0b49e80b-f206-4731-ab5a-61d53f99b595-53.c000.snappy.parquet under container isdweatherdatacontainer
# Done.
# ActivityCompleted: Activity=enrich, HowEnded=Success, Duration=47938.63 [ms]
# ActivityCompleted: Activity=enrich_customer_data_with_agg, HowEnded=Success, Duration=47957.08 [ms]
# ActivityStarted, get_enricher
# ActivityCompleted: Activity=get_enricher, HowEnded=Success, Duration=4.16 [ms]
# ActivityStarted, enrich_customer_data_with_agg
# ActivityStarted, enrich
# Target paths: ['/year=2013/month=1/']
# Looking for parquet files...
# Reading them into Pandas dataframe...
# Reading ISDWeather/year=2013/month=1/part-00007-tid-236689213593784421-264283c4-dffb-42b8-9bbf-d912ec6814af-73.c000.snappy.parquet under container isdweatherdatacontainer
# Done.
# ActivityCompleted: Activity=enrich, HowEnded=Success, Duration=43933.66 [ms]
# ActivityCompleted: Activity=enrich_customer_data_with_agg, HowEnded=Success, Duration=43967.35 [ms]
# ActivityStarted, get_enricher
# ActivityCompleted: Activity=get_enricher, HowEnded=Success, Duration=3.92 [ms]
# ActivityStarted, enrich_customer_data_with_agg
# ActivityStarted, enrich
# Target paths: ['/year=2013/month=2/']
# Looking for parquet files...
# Reading them into Pandas dataframe...
# Reading ISDWeather/year=2013/month=2/part-00011-tid-236689213593784421-264283c4-dffb-42b8-9bbf-d912ec6814af-77.c000.snappy.parquet under container isdweatherdatacontainer
# Done.
# ActivityCompleted: Activity=enrich, HowEnded=Success, Duration=40129.77 [ms]
# ActivityCompleted: Activity=enrich_customer_data_with_agg, HowEnded=Success, Duration=40162.76 [ms]
# ActivityStarted, get_enricher
# ActivityCompleted: Activity=get_enricher, HowEnded=Success, Duration=3.94 [ms]
# ActivityStarted, enrich_customer_data_with_agg
# ActivityStarted, enrich
# Target paths: ['/year=2013/month=3/']
# Looking for parquet files...
# Reading them into Pandas dataframe...
# Reading ISDWeather/year=2013/month=3/part-00008-tid-236689213593784421-264283c4-dffb-42b8-9bbf-d912ec6814af-74.c000.snappy.parquet under container isdweatherdatacontainer
# Done.
# ActivityCompleted: Activity=enrich, HowEnded=Success, Duration=46815.55 [ms]
# ActivityCompleted: Activity=enrich_customer_data_with_agg, HowEnded=Success, Duration=46832.82 [ms]
# ActivityStarted, get_enricher
# ActivityCompleted: Activity=get_enricher, HowEnded=Success, Duration=3.76 [ms]
# ActivityStarted, enrich_customer_data_with_agg
# ActivityStarted, enrich
# Target paths: ['/year=2013/month=4/']
# Looking for parquet files...
# Reading them into Pandas dataframe...
# Reading ISDWeather/year=2013/month=4/part-00010-tid-236689213593784421-264283c4-dffb-42b8-9bbf-d912ec6814af-76.c000.snappy.parquet under container isdweatherdatacontainer
# Done.
# ActivityCompleted: Activity=enrich, HowEnded=Success, Duration=127131.07 [ms]
# ActivityCompleted: Activity=enrich_customer_data_with_agg, HowEnded=Success, Duration=127149.5 [ms]
# ActivityStarted, get_enricher
# ActivityCompleted: Activity=get_enricher, HowEnded=Success, Duration=3.96 [ms]
# ActivityStarted, enrich_customer_data_with_agg
# ActivityStarted, enrich
# Target paths: ['/year=2013/month=5/']
# Looking for parquet files...
# Reading them into Pandas dataframe...
# Reading ISDWeather/year=2013/month=5/part-00003-tid-236689213593784421-264283c4-dffb-42b8-9bbf-d912ec6814af-69.c000.snappy.parquet under container isdweatherdatacontainer
# Done.
# ActivityCompleted: Activity=enrich, HowEnded=Success, Duration=52605.54 [ms]
# ActivityCompleted: Activity=enrich_customer_data_with_agg, HowEnded=Success, Duration=52612.71 [ms]
# ActivityStarted, get_enricher
# ActivityCompleted: Activity=get_enricher, HowEnded=Success, Duration=3.03 [ms]
# ActivityStarted, enrich_customer_data_with_agg
# ActivityStarted, enrich
# Target paths: ['/year=2013/month=6/']
# Looking for parquet files...
# Reading them into Pandas dataframe...
# Reading ISDWeather/year=2013/month=6/part-00005-tid-236689213593784421-264283c4-dffb-42b8-9bbf-d912ec6814af-71.c000.snappy.parquet under container isdweatherdatacontainer
# Done.
# ActivityCompleted: Activity=enrich, HowEnded=Success, Duration=44002.2 [ms]
# ActivityCompleted: Activity=enrich_customer_data_with_agg, HowEnded=Success, Duration=44015.14 [ms]
# ActivityStarted, get_enricher
# ActivityCompleted: Activity=get_enricher, HowEnded=Success, Duration=3.86 [ms]
# ActivityStarted, enrich_customer_data_with_agg
# ActivityStarted, enrich
# Target paths: ['/year=2013/month=7/']
# Looking for parquet files...
# Reading them into Pandas dataframe...
# Reading ISDWeather/year=2013/month=7/part-00004-tid-236689213593784421-264283c4-dffb-42b8-9bbf-d912ec6814af-70.c000.snappy.parquet under container isdweatherdatacontainer
# Done.
# ActivityCompleted: Activity=enrich, HowEnded=Success, Duration=42470.55 [ms]
# ActivityCompleted: Activity=enrich_customer_data_with_agg, HowEnded=Success, Duration=42499.55 [ms]
# ActivityStarted, get_enricher
# ActivityCompleted: Activity=get_enricher, HowEnded=Success, Duration=3.83 [ms]
# ActivityStarted, enrich_customer_data_with_agg
# ActivityStarted, enrich
# Target paths: ['/year=2013/month=8/']
# Looking for parquet files...
# Reading them into Pandas dataframe...
# Reading ISDWeather/year=2013/month=8/part-00001-tid-236689213593784421-264283c4-dffb-42b8-9bbf-d912ec6814af-67.c000.snappy.parquet under container isdweatherdatacontainer
# Done.
# ActivityCompleted: Activity=enrich, HowEnded=Success, Duration=50069.96 [ms]
# ActivityCompleted: Activity=enrich_customer_data_with_agg, HowEnded=Success, Duration=50091.1 [ms]
# ActivityStarted, get_enricher
# ActivityCompleted: Activity=get_enricher, HowEnded=Success, Duration=3.62 [ms]
# ActivityStarted, enrich_customer_data_with_agg
# ActivityStarted, enrich
# Target paths: ['/year=2013/month=9/']
# Looking for parquet files...
# Reading them into Pandas dataframe...
# Reading ISDWeather/year=2013/month=9/part-00006-tid-236689213593784421-264283c4-dffb-42b8-9bbf-d912ec6814af-72.c000.snappy.parquet under container isdweatherdatacontainer
# Done.
# ActivityCompleted: Activity=enrich, HowEnded=Success, Duration=42417.23 [ms]
# ActivityCompleted: Activity=enrich_customer_data_with_agg, HowEnded=Success, Duration=42428.04 [ms]
# ActivityStarted, get_enricher
# ActivityCompleted: Activity=get_enricher, HowEnded=Success, Duration=3.11 [ms]
# ActivityStarted, enrich_customer_data_with_agg
# ActivityStarted, enrich
# Target paths: ['/year=2013/month=10/']
# Looking for parquet files...
# Reading them into Pandas dataframe...
# Reading ISDWeather/year=2013/month=10/part-00000-tid-236689213593784421-264283c4-dffb-42b8-9bbf-d912ec6814af-66.c000.snappy.parquet under container isdweatherdatacontainer
# Done.
# ActivityCompleted: Activity=enrich, HowEnded=Success, Duration=42700.25 [ms]
# ActivityCompleted: Activity=enrich_customer_data_with_agg, HowEnded=Success, Duration=42719.53 [ms]
# ActivityStarted, get_enricher
# ActivityCompleted: Activity=get_enricher, HowEnded=Success, Duration=4.06 [ms]
# ActivityStarted, enrich_customer_data_with_agg
# ActivityStarted, enrich
# Target paths: ['/year=2013/month=11/']
# Looking for parquet files...
# Reading them into Pandas dataframe...
# Reading ISDWeather/year=2013/month=11/part-00009-tid-236689213593784421-264283c4-dffb-42b8-9bbf-d912ec6814af-75.c000.snappy.parquet under container isdweatherdatacontainer
# Done.
# ActivityCompleted: Activity=enrich, HowEnded=Success, Duration=42084.33 [ms]
# ActivityCompleted: Activity=enrich_customer_data_with_agg, HowEnded=Success, Duration=42105.99 [ms]
# ActivityStarted, get_enricher
# ActivityCompleted: Activity=get_enricher, HowEnded=Success, Duration=3.51 [ms]
# ActivityStarted, enrich_customer_data_with_agg
# ActivityStarted, enrich
# Target paths: ['/year=2013/month=12/']
# Looking for parquet files...
# Reading them into Pandas dataframe...
# Reading ISDWeather/year=2013/month=12/part-00002-tid-236689213593784421-264283c4-dffb-42b8-9bbf-d912ec6814af-68.c000.snappy.parquet under container isdweatherdatacontainer
# Done.
# ActivityCompleted: Activity=enrich, HowEnded=Success, Duration=41155.22 [ms]
# ActivityCompleted: Activity=enrich_customer_data_with_agg, HowEnded=Success, Duration=41178.37 [ms]
# ActivityStarted, get_enricher
# ActivityCompleted: Activity=get_enricher, HowEnded=Success, Duration=5.54 [ms]
# ActivityStarted, enrich_customer_data_with_agg
# ActivityStarted, enrich
# Target paths: ['/year=2014/month=1/']
# Looking for parquet files...
# Reading them into Pandas dataframe...
# Reading ISDWeather/year=2014/month=1/part-00000-tid-9219175779481662582-3729dfdb-ab32-4767-b9b6-11d2d644c3ce-79.c000.snappy.parquet under container isdweatherdatacontainer
# Done.
# ActivityCompleted: Activity=enrich, HowEnded=Success, Duration=41149.2 [ms]
# ActivityCompleted: Activity=enrich_customer_data_with_agg, HowEnded=Success, Duration=41168.78 [ms]
# ActivityStarted, get_enricher
# ActivityCompleted: Activity=get_enricher, HowEnded=Success, Duration=3.56 [ms]
# ActivityStarted, enrich_customer_data_with_agg
# ActivityStarted, enrich
# Target paths: ['/year=2014/month=2/']
# Looking for parquet files...
# Reading them into Pandas dataframe...
# Reading ISDWeather/year=2014/month=2/part-00011-tid-9219175779481662582-3729dfdb-ab32-4767-b9b6-11d2d644c3ce-90.c000.snappy.parquet under container isdweatherdatacontainer
# Done.
# ActivityCompleted: Activity=enrich, HowEnded=Success, Duration=40187.62 [ms]
# ActivityCompleted: Activity=enrich_customer_data_with_agg, HowEnded=Success, Duration=40220.08 [ms]
# ActivityStarted, get_enricher
# ActivityCompleted: Activity=get_enricher, HowEnded=Success, Duration=3.2 [ms]
# ActivityStarted, enrich_customer_data_with_agg
# ActivityStarted, enrich
# Target paths: ['/year=2014/month=3/']
# Looking for parquet files...
# Reading them into Pandas dataframe...
# Reading ISDWeather/year=2014/month=3/part-00001-tid-9219175779481662582-3729dfdb-ab32-4767-b9b6-11d2d644c3ce-80.c000.snappy.parquet under container isdweatherdatacontainer
# Done.
# ActivityCompleted: Activity=enrich, HowEnded=Success, Duration=50225.96 [ms]
# ActivityCompleted: Activity=enrich_customer_data_with_agg, HowEnded=Success, Duration=50243.52 [ms]
# ActivityStarted, get_enricher
# ActivityCompleted: Activity=get_enricher, HowEnded=Success, Duration=3.88 [ms]
# ActivityStarted, enrich_customer_data_with_agg
# ActivityStarted, enrich
# Target paths: ['/year=2014/month=4/']
# Looking for parquet files...
# Reading them into Pandas dataframe...
# Reading ISDWeather/year=2014/month=4/part-00006-tid-9219175779481662582-3729dfdb-ab32-4767-b9b6-11d2d644c3ce-85.c000.snappy.parquet under container isdweatherdatacontainer
# Done.
# ActivityCompleted: Activity=enrich, HowEnded=Success, Duration=40777.63 [ms]
# ActivityCompleted: Activity=enrich_customer_data_with_agg, HowEnded=Success, Duration=40809.99 [ms]
# ActivityStarted, get_enricher
# ActivityCompleted: Activity=get_enricher, HowEnded=Success, Duration=2.97 [ms]
# ActivityStarted, enrich_customer_data_with_agg
# ActivityStarted, enrich
# Target paths: ['/year=2014/month=5/']
# Looking for parquet files...
# Reading them into Pandas dataframe...
# Reading ISDWeather/year=2014/month=5/part-00003-tid-9219175779481662582-3729dfdb-ab32-4767-b9b6-11d2d644c3ce-82.c000.snappy.parquet under container isdweatherdatacontainer
# Done.
# ActivityCompleted: Activity=enrich, HowEnded=Success, Duration=44099.3 [ms]
# ActivityCompleted: Activity=enrich_customer_data_with_agg, HowEnded=Success, Duration=44116.36 [ms]
# ActivityStarted, get_enricher
# ActivityCompleted: Activity=get_enricher, HowEnded=Success, Duration=2.52 [ms]
# ActivityStarted, enrich_customer_data_with_agg
# ActivityStarted, enrich
# Target paths: ['/year=2014/month=6/']
# Looking for parquet files...
# Reading them into Pandas dataframe...
# Reading ISDWeather/year=2014/month=6/part-00010-tid-9219175779481662582-3729dfdb-ab32-4767-b9b6-11d2d644c3ce-89.c000.snappy.parquet under container isdweatherdatacontainer
# Done.
# ActivityCompleted: Activity=enrich, HowEnded=Success, Duration=40307.72 [ms]
# ActivityCompleted: Activity=enrich_customer_data_with_agg, HowEnded=Success, Duration=40328.8 [ms]
# ActivityStarted, get_enricher
# ActivityCompleted: Activity=get_enricher, HowEnded=Success, Duration=2.82 [ms]
# ActivityStarted, enrich_customer_data_with_agg
# ActivityStarted, enrich
# Target paths: ['/year=2014/month=7/']
# Looking for parquet files...
# Reading them into Pandas dataframe...
# Reading ISDWeather/year=2014/month=7/part-00009-tid-9219175779481662582-3729dfdb-ab32-4767-b9b6-11d2d644c3ce-88.c000.snappy.parquet under container isdweatherdatacontainer
# Done.
# ActivityCompleted: Activity=enrich, HowEnded=Success, Duration=50238.92 [ms]
# ActivityCompleted: Activity=enrich_customer_data_with_agg, HowEnded=Success, Duration=50279.23 [ms]
# ActivityStarted, get_enricher
# ActivityCompleted: Activity=get_enricher, HowEnded=Success, Duration=2.76 [ms]
# ActivityStarted, enrich_customer_data_with_agg
# ActivityStarted, enrich
# Target paths: ['/year=2014/month=8/']
# Looking for parquet files...
# Reading them into Pandas dataframe...
# Reading ISDWeather/year=2014/month=8/part-00005-tid-9219175779481662582-3729dfdb-ab32-4767-b9b6-11d2d644c3ce-84.c000.snappy.parquet under container isdweatherdatacontainer
# Done.
# ActivityCompleted: Activity=enrich, HowEnded=Success, Duration=46670.9 [ms]
# ActivityCompleted: Activity=enrich_customer_data_with_agg, HowEnded=Success, Duration=46705.8 [ms]
# ActivityStarted, get_enricher
# ActivityCompleted: Activity=get_enricher, HowEnded=Success, Duration=4.01 [ms]
# ActivityStarted, enrich_customer_data_with_agg
# ActivityStarted, enrich
# Target paths: ['/year=2014/month=9/']
# Looking for parquet files...
# Reading them into Pandas dataframe...
# Reading ISDWeather/year=2014/month=9/part-00007-tid-9219175779481662582-3729dfdb-ab32-4767-b9b6-11d2d644c3ce-86.c000.snappy.parquet under container isdweatherdatacontainer
# Done.
# ActivityCompleted: Activity=enrich, HowEnded=Success, Duration=39416.55 [ms]
# ActivityCompleted: Activity=enrich_customer_data_with_agg, HowEnded=Success, Duration=39433.73 [ms]
# ActivityStarted, get_enricher
# ActivityCompleted: Activity=get_enricher, HowEnded=Success, Duration=3.66 [ms]
# ActivityStarted, enrich_customer_data_with_agg
# ActivityStarted, enrich
# Target paths: ['/year=2014/month=10/']
# Looking for parquet files...
# Reading them into Pandas dataframe...
# Reading ISDWeather/year=2014/month=10/part-00002-tid-9219175779481662582-3729dfdb-ab32-4767-b9b6-11d2d644c3ce-81.c000.snappy.parquet under container isdweatherdatacontainer
# Done.
# ActivityCompleted: Activity=enrich, HowEnded=Success, Duration=46738.71 [ms]
# ActivityCompleted: Activity=enrich_customer_data_with_agg, HowEnded=Success, Duration=46747.18 [ms]
# ActivityStarted, get_enricher
# ActivityCompleted: Activity=get_enricher, HowEnded=Success, Duration=3.89 [ms]
# ActivityStarted, enrich_customer_data_with_agg
# ActivityStarted, enrich
# Target paths: ['/year=2014/month=11/']
# Looking for parquet files...
# Reading them into Pandas dataframe...
# Reading ISDWeather/year=2014/month=11/part-00008-tid-9219175779481662582-3729dfdb-ab32-4767-b9b6-11d2d644c3ce-87.c000.snappy.parquet under container isdweatherdatacontainer
# Done.
# ActivityCompleted: Activity=enrich, HowEnded=Success, Duration=43760.21 [ms]
# ActivityCompleted: Activity=enrich_customer_data_with_agg, HowEnded=Success, Duration=43777.68 [ms]
# ActivityStarted, get_enricher
# ActivityCompleted: Activity=get_enricher, HowEnded=Success, Duration=3.85 [ms]
# ActivityStarted, enrich_customer_data_with_agg
# ActivityStarted, enrich
# Target paths: ['/year=2014/month=12/']
# Looking for parquet files...
# Reading them into Pandas dataframe...
# Reading ISDWeather/year=2014/month=12/part-00004-tid-9219175779481662582-3729dfdb-ab32-4767-b9b6-11d2d644c3ce-83.c000.snappy.parquet under container isdweatherdatacontainer
# Done.
# ActivityCompleted: Activity=enrich, HowEnded=Success, Duration=45088.55 [ms]
# ActivityCompleted: Activity=enrich_customer_data_with_agg, HowEnded=Success, Duration=45120.62 [ms]
# ActivityStarted, get_enricher
# ActivityCompleted: Activity=get_enricher, HowEnded=Success, Duration=3.6 [ms]
# ActivityStarted, enrich_customer_data_with_agg
# ActivityStarted, enrich
# Target paths: ['/year=2015/month=1/']
# Looking for parquet files...
# Reading them into Pandas dataframe...
# Reading ISDWeather/year=2015/month=1/part-00006-tid-2198075741767757560-e3eb994e-d560-4dfc-941e-0aae74c8d9ed-98.c000.snappy.parquet under container isdweatherdatacontainer
# Done.
# ActivityCompleted: Activity=enrich, HowEnded=Success, Duration=51184.0 [ms]
# ActivityCompleted: Activity=enrich_customer_data_with_agg, HowEnded=Success, Duration=51217.77 [ms]
# ActivityStarted, get_enricher
# ActivityCompleted: Activity=get_enricher, HowEnded=Success, Duration=3.41 [ms]
# ActivityStarted, enrich_customer_data_with_agg
# ActivityStarted, enrich
# Target paths: ['/year=2015/month=2/']
# Looking for parquet files...
# Reading them into Pandas dataframe...
# Reading ISDWeather/year=2015/month=2/part-00010-tid-2198075741767757560-e3eb994e-d560-4dfc-941e-0aae74c8d9ed-102.c000.snappy.parquet under container isdweatherdatacontainer
# Done.
# ActivityCompleted: Activity=enrich, HowEnded=Success, Duration=46352.34 [ms]
# ActivityCompleted: Activity=enrich_customer_data_with_agg, HowEnded=Success, Duration=46386.13 [ms]
# ActivityStarted, get_enricher
# ActivityCompleted: Activity=get_enricher, HowEnded=Success, Duration=4.07 [ms]
# ActivityStarted, enrich_customer_data_with_agg
# ActivityStarted, enrich
# Target paths: ['/year=2015/month=3/']
# Looking for parquet files...
# Reading them into Pandas dataframe...
# Reading ISDWeather/year=2015/month=3/part-00005-tid-2198075741767757560-e3eb994e-d560-4dfc-941e-0aae74c8d9ed-97.c000.snappy.parquet under container isdweatherdatacontainer
# Done.
# ActivityCompleted: Activity=enrich, HowEnded=Success, Duration=40982.18 [ms]
# ActivityCompleted: Activity=enrich_customer_data_with_agg, HowEnded=Success, Duration=41015.66 [ms]
# ActivityStarted, get_enricher
# ActivityCompleted: Activity=get_enricher, HowEnded=Success, Duration=2.82 [ms]
# ActivityStarted, enrich_customer_data_with_agg
# ActivityStarted, enrich
# Target paths: ['/year=2015/month=4/']
# Looking for parquet files...
# Reading them into Pandas dataframe...
# Reading ISDWeather/year=2015/month=4/part-00011-tid-2198075741767757560-e3eb994e-d560-4dfc-941e-0aae74c8d9ed-103.c000.snappy.parquet under container isdweatherdatacontainer
# Done.
# ActivityCompleted: Activity=enrich, HowEnded=Success, Duration=25953.82 [ms]
# ActivityCompleted: Activity=enrich_customer_data_with_agg, HowEnded=Success, Duration=25967.18 [ms]
# ActivityStarted, get_enricher
# ActivityCompleted: Activity=get_enricher, HowEnded=Success, Duration=4.37 [ms]
# ActivityStarted, enrich_customer_data_with_agg
# ActivityStarted, enrich
# Target paths: ['/year=2015/month=5/']
# Looking for parquet files...
# Reading them into Pandas dataframe...
# Reading ISDWeather/year=2015/month=5/part-00001-tid-2198075741767757560-e3eb994e-d560-4dfc-941e-0aae74c8d9ed-93.c000.snappy.parquet under container isdweatherdatacontainer
# Done.
# ActivityCompleted: Activity=enrich, HowEnded=Success, Duration=42027.32 [ms]
# ActivityCompleted: Activity=enrich_customer_data_with_agg, HowEnded=Success, Duration=42045.71 [ms]
# ActivityStarted, get_enricher
# ActivityCompleted: Activity=get_enricher, HowEnded=Success, Duration=3.84 [ms]
# ActivityStarted, enrich_customer_data_with_agg
# ActivityStarted, enrich
# Target paths: ['/year=2015/month=6/']
# Looking for parquet files...
# Reading them into Pandas dataframe...
# Reading ISDWeather/year=2015/month=6/part-00008-tid-2198075741767757560-e3eb994e-d560-4dfc-941e-0aae74c8d9ed-100.c000.snappy.parquet under container isdweatherdatacontainer
# Done.
# ActivityCompleted: Activity=enrich, HowEnded=Success, Duration=40852.49 [ms]
# ActivityCompleted: Activity=enrich_customer_data_with_agg, HowEnded=Success, Duration=40870.1 [ms]
# ActivityStarted, get_enricher
# ActivityCompleted: Activity=get_enricher, HowEnded=Success, Duration=2.85 [ms]
# ActivityStarted, enrich_customer_data_with_agg
# ActivityStarted, enrich
# Target paths: ['/year=2015/month=7/']
# Looking for parquet files...
# Reading them into Pandas dataframe...
# Reading ISDWeather/year=2015/month=7/part-00004-tid-2198075741767757560-e3eb994e-d560-4dfc-941e-0aae74c8d9ed-96.c000.snappy.parquet under container isdweatherdatacontainer
# Done.
# ActivityCompleted: Activity=enrich, HowEnded=Success, Duration=43636.51 [ms]
# ActivityCompleted: Activity=enrich_customer_data_with_agg, HowEnded=Success, Duration=43670.44 [ms]
# ActivityStarted, get_enricher
# ActivityCompleted: Activity=get_enricher, HowEnded=Success, Duration=3.87 [ms]
# ActivityStarted, enrich_customer_data_with_agg
# ActivityStarted, enrich
# Target paths: ['/year=2015/month=8/']
# Looking for parquet files...
# Reading them into Pandas dataframe...
# Reading ISDWeather/year=2015/month=8/part-00007-tid-2198075741767757560-e3eb994e-d560-4dfc-941e-0aae74c8d9ed-99.c000.snappy.parquet under container isdweatherdatacontainer
# Done.
# ActivityCompleted: Activity=enrich, HowEnded=Success, Duration=44201.86 [ms]
# ActivityCompleted: Activity=enrich_customer_data_with_agg, HowEnded=Success, Duration=44236.14 [ms]
# ActivityStarted, get_enricher
# ActivityCompleted: Activity=get_enricher, HowEnded=Success, Duration=2.84 [ms]
# ActivityStarted, enrich_customer_data_with_agg
# ActivityStarted, enrich
# Target paths: ['/year=2015/month=9/']
# Looking for parquet files...
# Reading them into Pandas dataframe...
# Reading ISDWeather/year=2015/month=9/part-00009-tid-2198075741767757560-e3eb994e-d560-4dfc-941e-0aae74c8d9ed-101.c000.snappy.parquet under container isdweatherdatacontainer
# Done.
# ActivityCompleted: Activity=enrich, HowEnded=Success, Duration=43983.24 [ms]
# ActivityCompleted: Activity=enrich_customer_data_with_agg, HowEnded=Success, Duration=44013.22 [ms]
# ActivityStarted, get_enricher
# ActivityCompleted: Activity=get_enricher, HowEnded=Success, Duration=2.99 [ms]
# ActivityStarted, enrich_customer_data_with_agg
# ActivityStarted, enrich
# Target paths: ['/year=2015/month=10/']
# Looking for parquet files...
# Reading them into Pandas dataframe...
# Reading ISDWeather/year=2015/month=10/part-00002-tid-2198075741767757560-e3eb994e-d560-4dfc-941e-0aae74c8d9ed-94.c000.snappy.parquet under container isdweatherdatacontainer
# Done.
# ActivityCompleted: Activity=enrich, HowEnded=Success, Duration=43495.71 [ms]
# ActivityCompleted: Activity=enrich_customer_data_with_agg, HowEnded=Success, Duration=43524.34 [ms]
# ActivityStarted, get_enricher
# ActivityCompleted: Activity=get_enricher, HowEnded=Success, Duration=4.1 [ms]
# ActivityStarted, enrich_customer_data_with_agg
# ActivityStarted, enrich
# Target paths: ['/year=2015/month=11/']
# Looking for parquet files...
# Reading them into Pandas dataframe...
# Reading ISDWeather/year=2015/month=11/part-00003-tid-2198075741767757560-e3eb994e-d560-4dfc-941e-0aae74c8d9ed-95.c000.snappy.parquet under container isdweatherdatacontainer
# Done.
# ActivityCompleted: Activity=enrich, HowEnded=Success, Duration=77473.38 [ms]
# ActivityCompleted: Activity=enrich_customer_data_with_agg, HowEnded=Success, Duration=77505.54 [ms]
# ActivityStarted, get_enricher
# ActivityCompleted: Activity=get_enricher, HowEnded=Success, Duration=4.04 [ms]
# ActivityStarted, enrich_customer_data_with_agg
# ActivityStarted, enrich
# Target paths: ['/year=2015/month=12/']
# Looking for parquet files...
# Reading them into Pandas dataframe...
# Reading ISDWeather/year=2015/month=12/part-00000-tid-2198075741767757560-e3eb994e-d560-4dfc-941e-0aae74c8d9ed-92.c000.snappy.parquet under container isdweatherdatacontainer
# Done.
# ActivityCompleted: Activity=enrich, HowEnded=Success, Duration=54018.78 [ms]
# ActivityCompleted: Activity=enrich_customer_data_with_agg, HowEnded=Success, Duration=54051.63 [ms]
# ActivityStarted, get_enricher
# ActivityCompleted: Activity=get_enricher, HowEnded=Success, Duration=3.35 [ms]
# ActivityStarted, enrich_customer_data_with_agg
# ActivityStarted, enrich
# Target paths: ['/year=2016/month=1/']
# Looking for parquet files...
# Reading them into Pandas dataframe...
# Reading ISDWeather/year=2016/month=1/part-00005-tid-6700213360605767691-4491b75c-f137-489b-b5df-4204b9326fda-110.c000.snappy.parquet under container isdweatherdatacontainer
# Done.
# ActivityCompleted: Activity=enrich, HowEnded=Success, Duration=42586.04 [ms]
# ActivityCompleted: Activity=enrich_customer_data_with_agg, HowEnded=Success, Duration=42605.67 [ms]
# ActivityStarted, get_enricher
# ActivityCompleted: Activity=get_enricher, HowEnded=Success, Duration=7.07 [ms]
# ActivityStarted, enrich_customer_data_with_agg
# ActivityStarted, enrich
# Target paths: ['/year=2016/month=2/']
# Looking for parquet files...
# Reading them into Pandas dataframe...
# Reading ISDWeather/year=2016/month=2/part-00011-tid-6700213360605767691-4491b75c-f137-489b-b5df-4204b9326fda-116.c000.snappy.parquet under container isdweatherdatacontainer
# Done.
# ActivityCompleted: Activity=enrich, HowEnded=Success, Duration=40295.86 [ms]
# ActivityCompleted: Activity=enrich_customer_data_with_agg, HowEnded=Success, Duration=40313.37 [ms]
# ActivityStarted, get_enricher
# ActivityCompleted: Activity=get_enricher, HowEnded=Success, Duration=4.11 [ms]
# ActivityStarted, enrich_customer_data_with_agg
# ActivityStarted, enrich
# Target paths: ['/year=2016/month=3/']
# Looking for parquet files...
# Reading them into Pandas dataframe...
# Reading ISDWeather/year=2016/month=3/part-00004-tid-6700213360605767691-4491b75c-f137-489b-b5df-4204b9326fda-109.c000.snappy.parquet under container isdweatherdatacontainer
# Done.
# ActivityCompleted: Activity=enrich, HowEnded=Success, Duration=42776.65 [ms]
# ActivityCompleted: Activity=enrich_customer_data_with_agg, HowEnded=Success, Duration=42808.68 [ms]
# ActivityStarted, get_enricher
# ActivityCompleted: Activity=get_enricher, HowEnded=Success, Duration=3.84 [ms]
# ActivityStarted, enrich_customer_data_with_agg
# ActivityStarted, enrich
# Target paths: ['/year=2016/month=4/']
# Looking for parquet files...
# Reading them into Pandas dataframe...
# Reading ISDWeather/year=2016/month=4/part-00008-tid-6700213360605767691-4491b75c-f137-489b-b5df-4204b9326fda-113.c000.snappy.parquet under container isdweatherdatacontainer
# Done.
# ActivityCompleted: Activity=enrich, HowEnded=Success, Duration=43928.06 [ms]
# ActivityCompleted: Activity=enrich_customer_data_with_agg, HowEnded=Success, Duration=43948.75 [ms]
# ActivityStarted, get_enricher
# ActivityCompleted: Activity=get_enricher, HowEnded=Success, Duration=4.6 [ms]
# ActivityStarted, enrich_customer_data_with_agg
# ActivityStarted, enrich
# Target paths: ['/year=2016/month=5/']
# Looking for parquet files...
# Reading them into Pandas dataframe...
# Reading ISDWeather/year=2016/month=5/part-00006-tid-6700213360605767691-4491b75c-f137-489b-b5df-4204b9326fda-111.c000.snappy.parquet under container isdweatherdatacontainer
# Done.
# ActivityCompleted: Activity=enrich, HowEnded=Success, Duration=42744.48 [ms]
# ActivityCompleted: Activity=enrich_customer_data_with_agg, HowEnded=Success, Duration=42765.33 [ms]
# ActivityStarted, get_enricher
# ActivityCompleted: Activity=get_enricher, HowEnded=Success, Duration=3.89 [ms]
# ActivityStarted, enrich_customer_data_with_agg
# ActivityStarted, enrich
# Target paths: ['/year=2016/month=6/']
# Looking for parquet files...
# Reading them into Pandas dataframe...
# Reading ISDWeather/year=2016/month=6/part-00010-tid-6700213360605767691-4491b75c-f137-489b-b5df-4204b9326fda-115.c000.snappy.parquet under container isdweatherdatacontainer
# Done.
# ActivityCompleted: Activity=enrich, HowEnded=Success, Duration=41282.91 [ms]
# ActivityCompleted: Activity=enrich_customer_data_with_agg, HowEnded=Success, Duration=41301.75 [ms]
# ActivityStarted, get_enricher
# ActivityCompleted: Activity=get_enricher, HowEnded=Success, Duration=3.45 [ms]
# ActivityStarted, enrich_customer_data_with_agg
# ActivityStarted, enrich
# Target paths: ['/year=2016/month=7/']
# Looking for parquet files...
# Reading them into Pandas dataframe...
# Reading ISDWeather/year=2016/month=7/part-00003-tid-6700213360605767691-4491b75c-f137-489b-b5df-4204b9326fda-108.c000.snappy.parquet under container isdweatherdatacontainer
# Done.
# ActivityCompleted: Activity=enrich, HowEnded=Success, Duration=44100.42 [ms]
# ActivityCompleted: Activity=enrich_customer_data_with_agg, HowEnded=Success, Duration=44138.55 [ms]
# ActivityStarted, get_enricher
# ActivityCompleted: Activity=get_enricher, HowEnded=Success, Duration=3.44 [ms]
# ActivityStarted, enrich_customer_data_with_agg
# ActivityStarted, enrich
# Target paths: ['/year=2016/month=8/']
# Looking for parquet files...
# Reading them into Pandas dataframe...
# Reading ISDWeather/year=2016/month=8/part-00001-tid-6700213360605767691-4491b75c-f137-489b-b5df-4204b9326fda-106.c000.snappy.parquet under container isdweatherdatacontainer
# Done.
# ActivityCompleted: Activity=enrich, HowEnded=Success, Duration=55801.74 [ms]
# ActivityCompleted: Activity=enrich_customer_data_with_agg, HowEnded=Success, Duration=55833.24 [ms]
# ActivityStarted, get_enricher
# ActivityCompleted: Activity=get_enricher, HowEnded=Success, Duration=3.92 [ms]
# ActivityStarted, enrich_customer_data_with_agg
# ActivityStarted, enrich
# Target paths: ['/year=2016/month=9/']
# Looking for parquet files...
# Reading them into Pandas dataframe...
# Reading ISDWeather/year=2016/month=9/part-00007-tid-6700213360605767691-4491b75c-f137-489b-b5df-4204b9326fda-112.c000.snappy.parquet under container isdweatherdatacontainer
# Done.
# ActivityCompleted: Activity=enrich, HowEnded=Success, Duration=48032.31 [ms]
# ActivityCompleted: Activity=enrich_customer_data_with_agg, HowEnded=Success, Duration=48055.64 [ms]
# ActivityStarted, get_enricher
# ActivityCompleted: Activity=get_enricher, HowEnded=Success, Duration=4.05 [ms]
# ActivityStarted, enrich_customer_data_with_agg
# ActivityStarted, enrich
# Target paths: ['/year=2016/month=10/']
# Looking for parquet files...
# Reading them into Pandas dataframe...
# Reading ISDWeather/year=2016/month=10/part-00002-tid-6700213360605767691-4491b75c-f137-489b-b5df-4204b9326fda-107.c000.snappy.parquet under container isdweatherdatacontainer
# Done.
# ActivityCompleted: Activity=enrich, HowEnded=Success, Duration=46700.08 [ms]
# ActivityCompleted: Activity=enrich_customer_data_with_agg, HowEnded=Success, Duration=46736.0 [ms]
# ActivityStarted, get_enricher
# ActivityCompleted: Activity=get_enricher, HowEnded=Success, Duration=2.85 [ms]
# ActivityStarted, enrich_customer_data_with_agg
# ActivityStarted, enrich
# Target paths: ['/year=2016/month=11/']
# Looking for parquet files...
# Reading them into Pandas dataframe...
# Reading ISDWeather/year=2016/month=11/part-00009-tid-6700213360605767691-4491b75c-f137-489b-b5df-4204b9326fda-114.c000.snappy.parquet under container isdweatherdatacontainer
# Done.
# ActivityCompleted: Activity=enrich, HowEnded=Success, Duration=45431.99 [ms]
# ActivityCompleted: Activity=enrich_customer_data_with_agg, HowEnded=Success, Duration=45459.36 [ms]
# ActivityStarted, get_enricher
# ActivityCompleted: Activity=get_enricher, HowEnded=Success, Duration=3.7 [ms]
# ActivityStarted, enrich_customer_data_with_agg
# ActivityStarted, enrich
# Target paths: ['/year=2016/month=12/']
# Looking for parquet files...
# Reading them into Pandas dataframe...
# Reading ISDWeather/year=2016/month=12/part-00000-tid-6700213360605767691-4491b75c-f137-489b-b5df-4204b9326fda-105.c000.snappy.parquet under container isdweatherdatacontainer
# Done.
# ActivityCompleted: Activity=enrich, HowEnded=Success, Duration=43468.35 [ms]
# ActivityCompleted: Activity=enrich_customer_data_with_agg, HowEnded=Success, Duration=43509.73 [ms]
# ActivityStarted, get_enricher
# ActivityCompleted: Activity=get_enricher, HowEnded=Success, Duration=2.29 [ms]
# ActivityStarted, enrich_customer_data_with_agg
# ActivityStarted, enrich
# Target paths: ['/year=2017/month=1/']
# Looking for parquet files...
# Reading them into Pandas dataframe...
# Reading ISDWeather/year=2017/month=1/part-00001-tid-1321158002197267978-8e3eb092-4b7a-42de-97ee-e23297ed8955-119.c000.snappy.parquet under container isdweatherdatacontainer
# Done.
# ActivityCompleted: Activity=enrich, HowEnded=Success, Duration=45780.94 [ms]
# ActivityCompleted: Activity=enrich_customer_data_with_agg, HowEnded=Success, Duration=45815.66 [ms]
# ActivityStarted, get_enricher
# ActivityCompleted: Activity=get_enricher, HowEnded=Success, Duration=3.93 [ms]
# ActivityStarted, enrich_customer_data_with_agg
# ActivityStarted, enrich
# Target paths: ['/year=2017/month=2/']
# Looking for parquet files...
# Reading them into Pandas dataframe...
# Reading ISDWeather/year=2017/month=2/part-00011-tid-1321158002197267978-8e3eb092-4b7a-42de-97ee-e23297ed8955-129.c000.snappy.parquet under container isdweatherdatacontainer
# Done.
# ActivityCompleted: Activity=enrich, HowEnded=Success, Duration=43203.48 [ms]
# ActivityCompleted: Activity=enrich_customer_data_with_agg, HowEnded=Success, Duration=43223.95 [ms]
# ActivityStarted, get_enricher
# ActivityCompleted: Activity=get_enricher, HowEnded=Success, Duration=2.77 [ms]
# ActivityStarted, enrich_customer_data_with_agg
# ActivityStarted, enrich
# Target paths: ['/year=2017/month=3/']
# Looking for parquet files...
# Reading them into Pandas dataframe...
# Reading ISDWeather/year=2017/month=3/part-00000-tid-1321158002197267978-8e3eb092-4b7a-42de-97ee-e23297ed8955-118.c000.snappy.parquet under container isdweatherdatacontainer
# Done.
# ActivityCompleted: Activity=enrich, HowEnded=Success, Duration=53431.94 [ms]
# ActivityCompleted: Activity=enrich_customer_data_with_agg, HowEnded=Success, Duration=53449.64 [ms]
# ActivityStarted, get_enricher
# ActivityCompleted: Activity=get_enricher, HowEnded=Success, Duration=2.69 [ms]
# ActivityStarted, enrich_customer_data_with_agg
# ActivityStarted, enrich
# Target paths: ['/year=2017/month=4/']
# Looking for parquet files...
# Reading them into Pandas dataframe...
# Reading ISDWeather/year=2017/month=4/part-00007-tid-1321158002197267978-8e3eb092-4b7a-42de-97ee-e23297ed8955-125.c000.snappy.parquet under container isdweatherdatacontainer
# Done.
# ActivityCompleted: Activity=enrich, HowEnded=Success, Duration=42366.42 [ms]
# ActivityCompleted: Activity=enrich_customer_data_with_agg, HowEnded=Success, Duration=42383.67 [ms]
# ActivityStarted, get_enricher
# ActivityCompleted: Activity=get_enricher, HowEnded=Success, Duration=3.43 [ms]
# ActivityStarted, enrich_customer_data_with_agg
# ActivityStarted, enrich
# Target paths: ['/year=2017/month=5/']
# Looking for parquet files...
# Reading them into Pandas dataframe...
# Reading ISDWeather/year=2017/month=5/part-00002-tid-1321158002197267978-8e3eb092-4b7a-42de-97ee-e23297ed8955-120.c000.snappy.parquet under container isdweatherdatacontainer
# Done.
# ActivityCompleted: Activity=enrich, HowEnded=Success, Duration=47304.19 [ms]
# ActivityCompleted: Activity=enrich_customer_data_with_agg, HowEnded=Success, Duration=47322.27 [ms]
# ActivityStarted, get_enricher
# ActivityCompleted: Activity=get_enricher, HowEnded=Success, Duration=16.77 [ms]
# ActivityStarted, enrich_customer_data_with_agg
# ActivityStarted, enrich
# Target paths: ['/year=2017/month=6/']
# Looking for parquet files...
# Reading them into Pandas dataframe...
# Reading ISDWeather/year=2017/month=6/part-00010-tid-1321158002197267978-8e3eb092-4b7a-42de-97ee-e23297ed8955-128.c000.snappy.parquet under container isdweatherdatacontainer
# Done.
# ActivityCompleted: Activity=enrich, HowEnded=Success, Duration=46168.06 [ms]
# ActivityCompleted: Activity=enrich_customer_data_with_agg, HowEnded=Success, Duration=46194.71 [ms]
# ActivityStarted, get_enricher
# ActivityCompleted: Activity=get_enricher, HowEnded=Success, Duration=2.94 [ms]
# ActivityStarted, enrich_customer_data_with_agg
# ActivityStarted, enrich
# Target paths: ['/year=2017/month=7/']
# Looking for parquet files...
# Reading them into Pandas dataframe...
# Reading ISDWeather/year=2017/month=7/part-00006-tid-1321158002197267978-8e3eb092-4b7a-42de-97ee-e23297ed8955-124.c000.snappy.parquet under container isdweatherdatacontainer
# Done.
# ActivityCompleted: Activity=enrich, HowEnded=Success, Duration=45616.41 [ms]
# ActivityCompleted: Activity=enrich_customer_data_with_agg, HowEnded=Success, Duration=45647.94 [ms]
# ActivityStarted, get_enricher
# ActivityCompleted: Activity=get_enricher, HowEnded=Success, Duration=3.8 [ms]
# ActivityStarted, enrich_customer_data_with_agg
# ActivityStarted, enrich
# Target paths: ['/year=2017/month=8/']
# Looking for parquet files...
# Reading them into Pandas dataframe...
# Reading ISDWeather/year=2017/month=8/part-00003-tid-1321158002197267978-8e3eb092-4b7a-42de-97ee-e23297ed8955-121.c000.snappy.parquet under container isdweatherdatacontainer
# Done.
# ActivityCompleted: Activity=enrich, HowEnded=Success, Duration=32166.32 [ms]
# ActivityCompleted: Activity=enrich_customer_data_with_agg, HowEnded=Success, Duration=32199.33 [ms]
# [2019-04-26 07:40:00.921094] End enriching...

# %% [markdown]
# ### The final result has been saved to ``"./nyc_energy_enriched.csv"``

# %%
all.head(5)
# Out:
#              timeStamp  demand     lat    long            datetime  \
# 0  2012-01-01 00:00:00  4937.5  40.701 -74.009 2012-01-01 00:00:00
# 1  2012-01-01 01:00:00  4752.1  40.701 -74.009 2012-01-01 01:00:00
# 2  2012-01-01 02:00:00  4542.6  40.701 -74.009 2012-01-01 02:00:00
# 3  2012-01-01 03:00:00  4357.7  40.701 -74.009 2012-01-01 03:00:00
# 4  2012-01-01 04:00:00  4275.5  40.701 -74.009 2012-01-01 04:00:00
#
#    precipDepth  temperature  precipTime  snowDepth
# 0     0.773585     7.665934    2.896226        0.0
# 1     0.773585     7.665934    2.896226        0.0
# 2     0.773585     7.665934    2.896226        0.0
# 3     0.773585     7.665934    2.896226        0.0
# 4     0.773585     7.665934    2.896226        0.0

# %% [markdown]
# <font color='blue'>The join success rate is 100%</font>

# %%
all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 49205 entries, 0 to 270
# Data columns (total 9 columns):
# timeStamp      49205 non-null object
# demand         49124 non-null float64
# lat            49205 non-null float64
# long           49205 non-null float64
# datetime       49205 non-null datetime64[ns]
# precipDepth    49205 non-null float64
# temperature    49205 non-null float64
# precipTime     49205 non-null float64
# snowDepth      49205 non-null float64
# dtypes: datetime64[ns](1), float64(7), object(1)
# memory usage: 3.8+ MB

# %%
# EOF
