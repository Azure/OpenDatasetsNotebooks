# %% [markdown]
# # Load nyc_energy and enrich it with weather data
#
# In this notebook, we try to enrich the NYC Energy data in Jupyter Notebook in a scalable way.
# We enrich the input data by month, put the monthly enriched data in the temp folder, and save the final result in the current folder every time we have done one month.
#
# * Load csv file which is downloaded from:  https://notebooks.azure.com/frlazzeri/projects/automatedml-ms-build/html/nyc_energy.csv
# * Time range: 1/1/2012  to 8/12/2017
# * Location: 'PORT AUTH DOWNTN MANHATTAN WALL ST' station at <font color='red'>lat: 40.701, long: -74.009</font>

# %%
# install packages if it's not availble.

# !pip uninstall -y azureml-opendatasets
# !pip install azureml-opendatasets

# %% [markdown]
# ### Initialize global variables.

# %%
from datetime import datetime


start_date = datetime(2012, 1, 1, 0, 0)
end_date = datetime(2017, 8, 12, 23, 59)

start_date, end_date
# Out:
# (datetime.datetime(2012, 1, 1, 0, 0), datetime.datetime(2017, 8, 12, 23, 59))

# %%
from datetime import timedelta
from dateutil.relativedelta import relativedelta

import math


r = relativedelta(end_date, start_date)
months = r.years * 12 + r.months + math.floor((r.days + 30)/31)
months
# Out:
# 68

# %%
lat, long = 40.701, -74.009
lat, long
# Out:
# (40.701, -74.009)

# %% [markdown]
# ### Load ``"./nyc_energy.csv"`` (download and save to local) and preview the data.

# %%
from pandas import read_csv


df = read_csv('./nyc_energy.csv').drop(columns=['precip', 'temp'], axis=1)
df['lat'] = lat
df['long'] = long
df.head(5)
# Out:
#              timeStamp  demand     lat    long
# 0  2012-01-01 00:00:00  4937.5  40.701 -74.009
# 1  2012-01-01 01:00:00  4752.1  40.701 -74.009
# 2  2012-01-01 02:00:00  4542.6  40.701 -74.009
# 3  2012-01-01 03:00:00  4357.7  40.701 -74.009
# 4  2012-01-01 04:00:00  4275.5  40.701 -74.009

# %% [markdown]
# ### Extend the timeStamp column so that we can filter it easily.

# %%
from dateutil import parser


df['new_datetime'] = df['timeStamp'].apply(parser.parse)
raw_columns = list(df.columns)
df.head(5)
# Out:
#              timeStamp  demand     lat    long        new_datetime
# 0  2012-01-01 00:00:00  4937.5  40.701 -74.009 2012-01-01 00:00:00
# 1  2012-01-01 01:00:00  4752.1  40.701 -74.009 2012-01-01 01:00:00
# 2  2012-01-01 02:00:00  4542.6  40.701 -74.009 2012-01-01 02:00:00
# 3  2012-01-01 03:00:00  4357.7  40.701 -74.009 2012-01-01 03:00:00
# 4  2012-01-01 04:00:00  4275.5  40.701 -74.009 2012-01-01 04:00:00

# %% [markdown]
# ### Create the temp folder in which we save the enriched data per month.

# %%
# !if [ ! -d "./temp" ]; then mkdir temp; fi

# %% [markdown]
# ### Enriching...

# %%
import os.path
import pandas as pd
import numpy as np
from azureml.opendatasets.accessories.location_data import LatLongColumn
from azureml.opendatasets.accessories.location_time_customer_data \
    import LocationTimeCustomerData
from azureml.opendatasets import NoaaIsdWeather
from azureml.opendatasets.environ import PandasEnv


if os.path.exists('./nyc_energy_enriched.csv'):
    raise RuntimeError('nyc_energy_enriched.csv exists already.')
else:
    print('[%s] Start enriching...' % datetime.now())
    all = pd.DataFrame([])
    report_joined = {}
    i_date = start_date
    for m in range(months):
        j_date = i_date + relativedelta(months=1) - timedelta(milliseconds=1)

        # This is important to set monotonically increasing index for successful enrichemnt.
        df1 = df[(df['new_datetime'] >= i_date) & (df['new_datetime'] <= j_date)].copy()
        df1['idx'] = list(range(len(df1.index)))
        df1 = df1.set_index('idx')

        energy = LocationTimeCustomerData(
            df1,
            LatLongColumn('lat', 'long'),
            'new_datetime')

        weather = NoaaIsdWeather(
            cols=["temperature", "precipTime", "precipDepth", "snowDepth"],
            start_date=i_date,
            end_date=j_date)

        weather_enricher = weather.get_enricher()
        new_energy, processed_weather = weather_enricher.enrich_customer_data_no_agg(
            customer_data_object=energy,
            location_match_granularity=5, # higher for high join success rate, lower for performance.
            time_round_granularity='day')
        
        # ---=== Begin of cusomtized aggregation ===---
        
        processed_weather.data['precipDepth'] = processed_weather.data['precipDepth'].apply(
            lambda x: np.nan if x == 9999 else x)
        processed_weather.data['precipTime'] = processed_weather.data['precipTime'].apply(
            lambda x: np.nan if x == 99 else x)

        processed_weather.data['precipDepth/precipTime'] = \
        processed_weather.data[['precipDepth', 'precipTime']].apply(
            lambda x: np.nan if (
                pd.isna(x[0]) or pd.isna(x[1]) or x[1] == 0.0) else (x[0] / x[1]), axis=1)
        
        aggregations = {
            "temperature": "mean",
            "snowDepth": "mean",
            "precipDepth/precipTime": "mean",
            "precipDepth": "max",
            "precipTime": "max"}
        
        public_rankgroup = processed_weather.id

        public_join_time = [
            s for s in list(processed_weather.data.columns)
            if s.startswith('ds_join_time')][0]

        customer_rankgroup = weather_enricher.location_selector.customer_rankgroup

        customer_join_time = [
            s for s in list(new_energy.data.columns)
            if s.startswith('customer_join_time')][0]

        weather_df_grouped = processed_weather.data.groupby(
            by=[public_rankgroup, public_join_time]).agg(aggregations)
        
        joined_dataset = new_energy.data.merge(
            weather_df_grouped,
            left_on=[customer_rankgroup, customer_join_time],
            right_on=[public_rankgroup, public_join_time],
            how='left')

        final_df = joined_dataset[raw_columns + [
            "temperature", "precipTime", "precipDepth", "snowDepth", "precipDepth/precipTime"]]

        report_joined[i_date] = final_df.describe()
        
        # ---=== End of customized aggregation ===---
        
        fn = './temp/nyc_energy_enriched_%s.csv' % i_date
        final_df.to_csv(fn)

        all = pd.concat([all, final_df])
        all.to_csv('./nyc_energy_enriched.csv')

        i_date += relativedelta(months=1)

    print('[%s] End enriching...' % datetime.now())
# Out:
# [2019-04-29 09:00:03.181218] Start enriching...
# ActivityStarted, get_enricher
# ActivityCompleted: Activity=get_enricher, HowEnded=Success, Duration=21.29 [ms]
# ActivityStarted, enrich_customer_data_no_agg
# ActivityStarted, enrich
# Target paths: ['/year=2012/month=1/']
# Looking for parquet files...
# Reading them into Pandas dataframe...
# Reading ISDWeather/year=2012/month=1/part-00004-tid-7816671341480880202-0b49e80b-f206-4731-ab5a-61d53f99b595-57.c000.snappy.parquet under container isdweatherdatacontainer
# Done.
# ActivityCompleted: Activity=enrich, HowEnded=Success, Duration=84996.24 [ms]
# ActivityCompleted: Activity=enrich_customer_data_no_agg, HowEnded=Success, Duration=85094.1 [ms]
# ActivityStarted, get_enricher
# ActivityCompleted: Activity=get_enricher, HowEnded=Success, Duration=18.5 [ms]
# ActivityStarted, enrich_customer_data_no_agg
# ActivityStarted, enrich
# Target paths: ['/year=2012/month=2/']
# Looking for parquet files...
# Reading them into Pandas dataframe...
# Reading ISDWeather/year=2012/month=2/part-00011-tid-7816671341480880202-0b49e80b-f206-4731-ab5a-61d53f99b595-64.c000.snappy.parquet under container isdweatherdatacontainer
# Done.
# ActivityCompleted: Activity=enrich, HowEnded=Success, Duration=43456.5 [ms]
# ActivityCompleted: Activity=enrich_customer_data_no_agg, HowEnded=Success, Duration=43512.0 [ms]
# ActivityStarted, get_enricher
# ActivityCompleted: Activity=get_enricher, HowEnded=Success, Duration=16.26 [ms]
# ActivityStarted, enrich_customer_data_no_agg
# ActivityStarted, enrich
# Target paths: ['/year=2012/month=3/']
# Looking for parquet files...
# Reading them into Pandas dataframe...
# Reading ISDWeather/year=2012/month=3/part-00001-tid-7816671341480880202-0b49e80b-f206-4731-ab5a-61d53f99b595-54.c000.snappy.parquet under container isdweatherdatacontainer
# Done.
# ActivityCompleted: Activity=enrich, HowEnded=Success, Duration=45698.45 [ms]
# ActivityCompleted: Activity=enrich_customer_data_no_agg, HowEnded=Success, Duration=45803.06 [ms]
# ActivityStarted, get_enricher
# ActivityCompleted: Activity=get_enricher, HowEnded=Success, Duration=17.27 [ms]
# ActivityStarted, enrich_customer_data_no_agg
# ActivityStarted, enrich
# Target paths: ['/year=2012/month=4/']
# Looking for parquet files...
# Reading them into Pandas dataframe...
# Reading ISDWeather/year=2012/month=4/part-00005-tid-7816671341480880202-0b49e80b-f206-4731-ab5a-61d53f99b595-58.c000.snappy.parquet under container isdweatherdatacontainer
# Done.
# ActivityCompleted: Activity=enrich, HowEnded=Success, Duration=54456.14 [ms]
# ActivityCompleted: Activity=enrich_customer_data_no_agg, HowEnded=Success, Duration=54511.25 [ms]
# ActivityStarted, get_enricher
# ActivityCompleted: Activity=get_enricher, HowEnded=Success, Duration=19.45 [ms]
# ActivityStarted, enrich_customer_data_no_agg
# ActivityStarted, enrich
# Target paths: ['/year=2012/month=5/']
# Looking for parquet files...
# Reading them into Pandas dataframe...
# Reading ISDWeather/year=2012/month=5/part-00003-tid-7816671341480880202-0b49e80b-f206-4731-ab5a-61d53f99b595-56.c000.snappy.parquet under container isdweatherdatacontainer
# Done.
# ActivityCompleted: Activity=enrich, HowEnded=Success, Duration=44063.01 [ms]
# ActivityCompleted: Activity=enrich_customer_data_no_agg, HowEnded=Success, Duration=44118.81 [ms]
# ActivityStarted, get_enricher
# ActivityCompleted: Activity=get_enricher, HowEnded=Success, Duration=17.76 [ms]
# ActivityStarted, enrich_customer_data_no_agg
# ActivityStarted, enrich
# Target paths: ['/year=2012/month=6/']
# Looking for parquet files...
# Reading them into Pandas dataframe...
# Reading ISDWeather/year=2012/month=6/part-00010-tid-7816671341480880202-0b49e80b-f206-4731-ab5a-61d53f99b595-63.c000.snappy.parquet under container isdweatherdatacontainer
# Done.
# ActivityCompleted: Activity=enrich, HowEnded=Success, Duration=45127.85 [ms]
# ActivityCompleted: Activity=enrich_customer_data_no_agg, HowEnded=Success, Duration=45182.84 [ms]
# ActivityStarted, get_enricher
# ActivityCompleted: Activity=get_enricher, HowEnded=Success, Duration=17.56 [ms]
# ActivityStarted, enrich_customer_data_no_agg
# ActivityStarted, enrich
# Target paths: ['/year=2012/month=7/']
# Looking for parquet files...
# Reading them into Pandas dataframe...
# Reading ISDWeather/year=2012/month=7/part-00006-tid-7816671341480880202-0b49e80b-f206-4731-ab5a-61d53f99b595-59.c000.snappy.parquet under container isdweatherdatacontainer
# Done.
# ActivityCompleted: Activity=enrich, HowEnded=Success, Duration=75718.52 [ms]
# ActivityCompleted: Activity=enrich_customer_data_no_agg, HowEnded=Success, Duration=75780.16 [ms]
# ActivityStarted, get_enricher
# ActivityCompleted: Activity=get_enricher, HowEnded=Success, Duration=17.76 [ms]
# ActivityStarted, enrich_customer_data_no_agg
# ActivityStarted, enrich
# Target paths: ['/year=2012/month=8/']
# Looking for parquet files...
# Reading them into Pandas dataframe...
# Reading ISDWeather/year=2012/month=8/part-00007-tid-7816671341480880202-0b49e80b-f206-4731-ab5a-61d53f99b595-60.c000.snappy.parquet under container isdweatherdatacontainer
# Done.
# ActivityCompleted: Activity=enrich, HowEnded=Success, Duration=129134.28 [ms]
# ActivityCompleted: Activity=enrich_customer_data_no_agg, HowEnded=Success, Duration=129187.24 [ms]
# ActivityStarted, get_enricher
# ActivityCompleted: Activity=get_enricher, HowEnded=Success, Duration=21.15 [ms]
# ActivityStarted, enrich_customer_data_no_agg
# ActivityStarted, enrich
# Target paths: ['/year=2012/month=9/']
# Looking for parquet files...
# Reading them into Pandas dataframe...
# Reading ISDWeather/year=2012/month=9/part-00008-tid-7816671341480880202-0b49e80b-f206-4731-ab5a-61d53f99b595-61.c000.snappy.parquet under container isdweatherdatacontainer
# Done.
# ActivityCompleted: Activity=enrich, HowEnded=Success, Duration=42776.43 [ms]
# ActivityCompleted: Activity=enrich_customer_data_no_agg, HowEnded=Success, Duration=42830.6 [ms]
# ActivityStarted, get_enricher
# ActivityCompleted: Activity=get_enricher, HowEnded=Success, Duration=20.45 [ms]
# ActivityStarted, enrich_customer_data_no_agg
# ActivityStarted, enrich
# Target paths: ['/year=2012/month=10/']
# Looking for parquet files...
# Reading them into Pandas dataframe...
# Reading ISDWeather/year=2012/month=10/part-00002-tid-7816671341480880202-0b49e80b-f206-4731-ab5a-61d53f99b595-55.c000.snappy.parquet under container isdweatherdatacontainer
# Done.
# ActivityCompleted: Activity=enrich, HowEnded=Success, Duration=45559.84 [ms]
# ActivityCompleted: Activity=enrich_customer_data_no_agg, HowEnded=Success, Duration=45615.31 [ms]
# ActivityStarted, get_enricher
# ActivityCompleted: Activity=get_enricher, HowEnded=Success, Duration=17.28 [ms]
# ActivityStarted, enrich_customer_data_no_agg
# ActivityStarted, enrich
# Target paths: ['/year=2012/month=11/']
# Looking for parquet files...
# Reading them into Pandas dataframe...
# Reading ISDWeather/year=2012/month=11/part-00009-tid-7816671341480880202-0b49e80b-f206-4731-ab5a-61d53f99b595-62.c000.snappy.parquet under container isdweatherdatacontainer
# Done.
# ActivityCompleted: Activity=enrich, HowEnded=Success, Duration=44528.69 [ms]
# ActivityCompleted: Activity=enrich_customer_data_no_agg, HowEnded=Success, Duration=44578.58 [ms]
# ActivityStarted, get_enricher
# ActivityCompleted: Activity=get_enricher, HowEnded=Success, Duration=18.67 [ms]
# ActivityStarted, enrich_customer_data_no_agg
# ActivityStarted, enrich
# Target paths: ['/year=2012/month=12/']
# Looking for parquet files...
# Reading them into Pandas dataframe...
# Reading ISDWeather/year=2012/month=12/part-00000-tid-7816671341480880202-0b49e80b-f206-4731-ab5a-61d53f99b595-53.c000.snappy.parquet under container isdweatherdatacontainer
# Done.
# ActivityCompleted: Activity=enrich, HowEnded=Success, Duration=88248.81 [ms]
# ActivityCompleted: Activity=enrich_customer_data_no_agg, HowEnded=Success, Duration=88308.84 [ms]
# ActivityStarted, get_enricher
# ActivityCompleted: Activity=get_enricher, HowEnded=Success, Duration=17.71 [ms]
# ActivityStarted, enrich_customer_data_no_agg
# ActivityStarted, enrich
# Target paths: ['/year=2013/month=1/']
# Looking for parquet files...
# Reading them into Pandas dataframe...
# Reading ISDWeather/year=2013/month=1/part-00007-tid-236689213593784421-264283c4-dffb-42b8-9bbf-d912ec6814af-73.c000.snappy.parquet under container isdweatherdatacontainer
# Done.
# ActivityCompleted: Activity=enrich, HowEnded=Success, Duration=44205.78 [ms]
# ActivityCompleted: Activity=enrich_customer_data_no_agg, HowEnded=Success, Duration=44269.14 [ms]
# ActivityStarted, get_enricher
# ActivityCompleted: Activity=get_enricher, HowEnded=Success, Duration=17.68 [ms]
# ActivityStarted, enrich_customer_data_no_agg
# ActivityStarted, enrich
# Target paths: ['/year=2013/month=2/']
# Looking for parquet files...
# Reading them into Pandas dataframe...
# Reading ISDWeather/year=2013/month=2/part-00011-tid-236689213593784421-264283c4-dffb-42b8-9bbf-d912ec6814af-77.c000.snappy.parquet under container isdweatherdatacontainer
# Done.
# ActivityCompleted: Activity=enrich, HowEnded=Success, Duration=62644.02 [ms]
# ActivityCompleted: Activity=enrich_customer_data_no_agg, HowEnded=Success, Duration=62696.92 [ms]
# ActivityStarted, get_enricher
# ActivityCompleted: Activity=get_enricher, HowEnded=Success, Duration=21.12 [ms]
# ActivityStarted, enrich_customer_data_no_agg
# ActivityStarted, enrich
# Target paths: ['/year=2013/month=3/']
# Looking for parquet files...
# Reading them into Pandas dataframe...
# Reading ISDWeather/year=2013/month=3/part-00008-tid-236689213593784421-264283c4-dffb-42b8-9bbf-d912ec6814af-74.c000.snappy.parquet under container isdweatherdatacontainer
# Done.
# ActivityCompleted: Activity=enrich, HowEnded=Success, Duration=63616.67 [ms]
# ActivityCompleted: Activity=enrich_customer_data_no_agg, HowEnded=Success, Duration=63668.2 [ms]
# ActivityStarted, get_enricher
# ActivityCompleted: Activity=get_enricher, HowEnded=Success, Duration=18.23 [ms]
# ActivityStarted, enrich_customer_data_no_agg
# ActivityStarted, enrich
# Target paths: ['/year=2013/month=4/']
# Looking for parquet files...
# Reading them into Pandas dataframe...
# Reading ISDWeather/year=2013/month=4/part-00010-tid-236689213593784421-264283c4-dffb-42b8-9bbf-d912ec6814af-76.c000.snappy.parquet under container isdweatherdatacontainer
# Done.
# ActivityCompleted: Activity=enrich, HowEnded=Success, Duration=44978.72 [ms]
# ActivityCompleted: Activity=enrich_customer_data_no_agg, HowEnded=Success, Duration=45061.97 [ms]
# ActivityStarted, get_enricher
# ActivityCompleted: Activity=get_enricher, HowEnded=Success, Duration=17.39 [ms]
# ActivityStarted, enrich_customer_data_no_agg
# ActivityStarted, enrich
# Target paths: ['/year=2013/month=5/']
# Looking for parquet files...
# Reading them into Pandas dataframe...
# Reading ISDWeather/year=2013/month=5/part-00003-tid-236689213593784421-264283c4-dffb-42b8-9bbf-d912ec6814af-69.c000.snappy.parquet under container isdweatherdatacontainer
# Done.
# ActivityCompleted: Activity=enrich, HowEnded=Success, Duration=44434.92 [ms]
# ActivityCompleted: Activity=enrich_customer_data_no_agg, HowEnded=Success, Duration=44490.32 [ms]
# ActivityStarted, get_enricher
# ActivityCompleted: Activity=get_enricher, HowEnded=Success, Duration=16.25 [ms]
# ActivityStarted, enrich_customer_data_no_agg
# ActivityStarted, enrich
# Target paths: ['/year=2013/month=6/']
# Looking for parquet files...
# Reading them into Pandas dataframe...
# Reading ISDWeather/year=2013/month=6/part-00005-tid-236689213593784421-264283c4-dffb-42b8-9bbf-d912ec6814af-71.c000.snappy.parquet under container isdweatherdatacontainer
# Done.
# ActivityCompleted: Activity=enrich, HowEnded=Success, Duration=42086.7 [ms]
# ActivityCompleted: Activity=enrich_customer_data_no_agg, HowEnded=Success, Duration=42142.35 [ms]
# ActivityStarted, get_enricher
# ActivityCompleted: Activity=get_enricher, HowEnded=Success, Duration=18.83 [ms]
# ActivityStarted, enrich_customer_data_no_agg
# ActivityStarted, enrich
# Target paths: ['/year=2013/month=7/']
# Looking for parquet files...
# Reading them into Pandas dataframe...
# Reading ISDWeather/year=2013/month=7/part-00004-tid-236689213593784421-264283c4-dffb-42b8-9bbf-d912ec6814af-70.c000.snappy.parquet under container isdweatherdatacontainer
# Done.
# ActivityCompleted: Activity=enrich, HowEnded=Success, Duration=41910.92 [ms]
# ActivityCompleted: Activity=enrich_customer_data_no_agg, HowEnded=Success, Duration=41964.88 [ms]
# ActivityStarted, get_enricher
# ActivityCompleted: Activity=get_enricher, HowEnded=Success, Duration=13.26 [ms]
# ActivityStarted, enrich_customer_data_no_agg
# ActivityStarted, enrich
# Target paths: ['/year=2013/month=8/']
# Looking for parquet files...
# Reading them into Pandas dataframe...
# Reading ISDWeather/year=2013/month=8/part-00001-tid-236689213593784421-264283c4-dffb-42b8-9bbf-d912ec6814af-67.c000.snappy.parquet under container isdweatherdatacontainer
# Done.
# ActivityCompleted: Activity=enrich, HowEnded=Success, Duration=46636.82 [ms]
# ActivityCompleted: Activity=enrich_customer_data_no_agg, HowEnded=Success, Duration=46692.14 [ms]
# ActivityStarted, get_enricher
# ActivityCompleted: Activity=get_enricher, HowEnded=Success, Duration=17.81 [ms]
# ActivityStarted, enrich_customer_data_no_agg
# ActivityStarted, enrich
# Target paths: ['/year=2013/month=9/']
# Looking for parquet files...
# Reading them into Pandas dataframe...
# Reading ISDWeather/year=2013/month=9/part-00006-tid-236689213593784421-264283c4-dffb-42b8-9bbf-d912ec6814af-72.c000.snappy.parquet under container isdweatherdatacontainer
# Done.
# ActivityCompleted: Activity=enrich, HowEnded=Success, Duration=46989.72 [ms]
# ActivityCompleted: Activity=enrich_customer_data_no_agg, HowEnded=Success, Duration=47071.96 [ms]
# ActivityStarted, get_enricher
# ActivityCompleted: Activity=get_enricher, HowEnded=Success, Duration=11.18 [ms]
# ActivityStarted, enrich_customer_data_no_agg
# ActivityStarted, enrich
# Target paths: ['/year=2013/month=10/']
# Looking for parquet files...
# Reading them into Pandas dataframe...
# Reading ISDWeather/year=2013/month=10/part-00000-tid-236689213593784421-264283c4-dffb-42b8-9bbf-d912ec6814af-66.c000.snappy.parquet under container isdweatherdatacontainer
# Done.
# ActivityCompleted: Activity=enrich, HowEnded=Success, Duration=162179.34 [ms]
# ActivityCompleted: Activity=enrich_customer_data_no_agg, HowEnded=Success, Duration=162226.64 [ms]
# ActivityStarted, get_enricher
# ActivityCompleted: Activity=get_enricher, HowEnded=Success, Duration=16.66 [ms]
# ActivityStarted, enrich_customer_data_no_agg
# ActivityStarted, enrich
# Target paths: ['/year=2013/month=11/']
# Looking for parquet files...
# Reading them into Pandas dataframe...
# Reading ISDWeather/year=2013/month=11/part-00009-tid-236689213593784421-264283c4-dffb-42b8-9bbf-d912ec6814af-75.c000.snappy.parquet under container isdweatherdatacontainer
# Done.
# ActivityCompleted: Activity=enrich, HowEnded=Success, Duration=43066.49 [ms]
# ActivityCompleted: Activity=enrich_customer_data_no_agg, HowEnded=Success, Duration=43117.76 [ms]
# ActivityStarted, get_enricher
# ActivityCompleted: Activity=get_enricher, HowEnded=Success, Duration=21.52 [ms]
# ActivityStarted, enrich_customer_data_no_agg
# ActivityStarted, enrich
# Target paths: ['/year=2013/month=12/']
# Looking for parquet files...
# Reading them into Pandas dataframe...
# Reading ISDWeather/year=2013/month=12/part-00002-tid-236689213593784421-264283c4-dffb-42b8-9bbf-d912ec6814af-68.c000.snappy.parquet under container isdweatherdatacontainer
# Done.
# ActivityCompleted: Activity=enrich, HowEnded=Success, Duration=45187.0 [ms]
# ActivityCompleted: Activity=enrich_customer_data_no_agg, HowEnded=Success, Duration=45230.84 [ms]
# ActivityStarted, get_enricher
# ActivityCompleted: Activity=get_enricher, HowEnded=Success, Duration=21.41 [ms]
# ActivityStarted, enrich_customer_data_no_agg
# ActivityStarted, enrich
# Target paths: ['/year=2014/month=1/']
# Looking for parquet files...
# Reading them into Pandas dataframe...
# Reading ISDWeather/year=2014/month=1/part-00000-tid-9219175779481662582-3729dfdb-ab32-4767-b9b6-11d2d644c3ce-79.c000.snappy.parquet under container isdweatherdatacontainer
# Done.
# ActivityCompleted: Activity=enrich, HowEnded=Success, Duration=49615.68 [ms]
# ActivityCompleted: Activity=enrich_customer_data_no_agg, HowEnded=Success, Duration=49671.23 [ms]
# ActivityStarted, get_enricher
# ActivityCompleted: Activity=get_enricher, HowEnded=Success, Duration=13.47 [ms]
# ActivityStarted, enrich_customer_data_no_agg
# ActivityStarted, enrich
# Target paths: ['/year=2014/month=2/']
# Looking for parquet files...
# Reading them into Pandas dataframe...
# Reading ISDWeather/year=2014/month=2/part-00011-tid-9219175779481662582-3729dfdb-ab32-4767-b9b6-11d2d644c3ce-90.c000.snappy.parquet under container isdweatherdatacontainer
# Done.
# ActivityCompleted: Activity=enrich, HowEnded=Success, Duration=44652.11 [ms]
# ActivityCompleted: Activity=enrich_customer_data_no_agg, HowEnded=Success, Duration=44703.73 [ms]
# ActivityStarted, get_enricher
# ActivityCompleted: Activity=get_enricher, HowEnded=Success, Duration=17.69 [ms]
# ActivityStarted, enrich_customer_data_no_agg
# ActivityStarted, enrich
# Target paths: ['/year=2014/month=3/']
# Looking for parquet files...
# Reading them into Pandas dataframe...
# Reading ISDWeather/year=2014/month=3/part-00001-tid-9219175779481662582-3729dfdb-ab32-4767-b9b6-11d2d644c3ce-80.c000.snappy.parquet under container isdweatherdatacontainer
# Done.
# ActivityCompleted: Activity=enrich, HowEnded=Success, Duration=43063.67 [ms]
# ActivityCompleted: Activity=enrich_customer_data_no_agg, HowEnded=Success, Duration=43116.56 [ms]
# ActivityStarted, get_enricher
# ActivityCompleted: Activity=get_enricher, HowEnded=Success, Duration=16.72 [ms]
# ActivityStarted, enrich_customer_data_no_agg
# ActivityStarted, enrich
# Target paths: ['/year=2014/month=4/']
# Looking for parquet files...
# Reading them into Pandas dataframe...
# Reading ISDWeather/year=2014/month=4/part-00006-tid-9219175779481662582-3729dfdb-ab32-4767-b9b6-11d2d644c3ce-85.c000.snappy.parquet under container isdweatherdatacontainer
# Done.
# ActivityCompleted: Activity=enrich, HowEnded=Success, Duration=57670.61 [ms]
# ActivityCompleted: Activity=enrich_customer_data_no_agg, HowEnded=Success, Duration=57753.74 [ms]
# ActivityStarted, get_enricher
# ActivityCompleted: Activity=get_enricher, HowEnded=Success, Duration=11.64 [ms]
# ActivityStarted, enrich_customer_data_no_agg
# ActivityStarted, enrich
# Target paths: ['/year=2014/month=5/']
# Looking for parquet files...
# Reading them into Pandas dataframe...
# Reading ISDWeather/year=2014/month=5/part-00003-tid-9219175779481662582-3729dfdb-ab32-4767-b9b6-11d2d644c3ce-82.c000.snappy.parquet under container isdweatherdatacontainer
# Done.
# ActivityCompleted: Activity=enrich, HowEnded=Success, Duration=47830.11 [ms]
# ActivityCompleted: Activity=enrich_customer_data_no_agg, HowEnded=Success, Duration=47883.77 [ms]
# ActivityStarted, get_enricher
# ActivityCompleted: Activity=get_enricher, HowEnded=Success, Duration=20.26 [ms]
# ActivityStarted, enrich_customer_data_no_agg
# ActivityStarted, enrich
# Target paths: ['/year=2014/month=6/']
# Looking for parquet files...
# Reading them into Pandas dataframe...
# Reading ISDWeather/year=2014/month=6/part-00010-tid-9219175779481662582-3729dfdb-ab32-4767-b9b6-11d2d644c3ce-89.c000.snappy.parquet under container isdweatherdatacontainer
# Done.
# ActivityCompleted: Activity=enrich, HowEnded=Success, Duration=41722.47 [ms]
# ActivityCompleted: Activity=enrich_customer_data_no_agg, HowEnded=Success, Duration=41783.46 [ms]
# ActivityStarted, get_enricher
# ActivityCompleted: Activity=get_enricher, HowEnded=Success, Duration=17.44 [ms]
# ActivityStarted, enrich_customer_data_no_agg
# ActivityStarted, enrich
# Target paths: ['/year=2014/month=7/']
# Looking for parquet files...
# Reading them into Pandas dataframe...
# Reading ISDWeather/year=2014/month=7/part-00009-tid-9219175779481662582-3729dfdb-ab32-4767-b9b6-11d2d644c3ce-88.c000.snappy.parquet under container isdweatherdatacontainer
# Done.
# ActivityCompleted: Activity=enrich, HowEnded=Success, Duration=42955.4 [ms]
# ActivityCompleted: Activity=enrich_customer_data_no_agg, HowEnded=Success, Duration=43005.24 [ms]
# ActivityStarted, get_enricher
# ActivityCompleted: Activity=get_enricher, HowEnded=Success, Duration=21.54 [ms]
# ActivityStarted, enrich_customer_data_no_agg
# ActivityStarted, enrich
# Target paths: ['/year=2014/month=8/']
# Looking for parquet files...
# Reading them into Pandas dataframe...
# Reading ISDWeather/year=2014/month=8/part-00005-tid-9219175779481662582-3729dfdb-ab32-4767-b9b6-11d2d644c3ce-84.c000.snappy.parquet under container isdweatherdatacontainer
# Done.
# ActivityCompleted: Activity=enrich, HowEnded=Success, Duration=42296.2 [ms]
# ActivityCompleted: Activity=enrich_customer_data_no_agg, HowEnded=Success, Duration=42380.61 [ms]
# ActivityStarted, get_enricher
# ActivityCompleted: Activity=get_enricher, HowEnded=Success, Duration=19.23 [ms]
# ActivityStarted, enrich_customer_data_no_agg
# ActivityStarted, enrich
# Target paths: ['/year=2014/month=9/']
# Looking for parquet files...
# Reading them into Pandas dataframe...
# Reading ISDWeather/year=2014/month=9/part-00007-tid-9219175779481662582-3729dfdb-ab32-4767-b9b6-11d2d644c3ce-86.c000.snappy.parquet under container isdweatherdatacontainer
# Done.
# ActivityCompleted: Activity=enrich, HowEnded=Success, Duration=48054.2 [ms]
# ActivityCompleted: Activity=enrich_customer_data_no_agg, HowEnded=Success, Duration=48104.44 [ms]
# ActivityStarted, get_enricher
# ActivityCompleted: Activity=get_enricher, HowEnded=Success, Duration=17.48 [ms]
# ActivityStarted, enrich_customer_data_no_agg
# ActivityStarted, enrich
# Target paths: ['/year=2014/month=10/']
# Looking for parquet files...
# Reading them into Pandas dataframe...
# Reading ISDWeather/year=2014/month=10/part-00002-tid-9219175779481662582-3729dfdb-ab32-4767-b9b6-11d2d644c3ce-81.c000.snappy.parquet under container isdweatherdatacontainer
# Done.
# ActivityCompleted: Activity=enrich, HowEnded=Success, Duration=44798.42 [ms]
# ActivityCompleted: Activity=enrich_customer_data_no_agg, HowEnded=Success, Duration=44854.57 [ms]
# ActivityStarted, get_enricher
# ActivityCompleted: Activity=get_enricher, HowEnded=Success, Duration=19.53 [ms]
# ActivityStarted, enrich_customer_data_no_agg
# ActivityStarted, enrich
# Target paths: ['/year=2014/month=11/']
# Looking for parquet files...
# Reading them into Pandas dataframe...
# Reading ISDWeather/year=2014/month=11/part-00008-tid-9219175779481662582-3729dfdb-ab32-4767-b9b6-11d2d644c3ce-87.c000.snappy.parquet under container isdweatherdatacontainer
# Done.
# ActivityCompleted: Activity=enrich, HowEnded=Success, Duration=47152.97 [ms]
# ActivityCompleted: Activity=enrich_customer_data_no_agg, HowEnded=Success, Duration=47238.21 [ms]
# ActivityStarted, get_enricher
# ActivityCompleted: Activity=get_enricher, HowEnded=Success, Duration=18.0 [ms]
# ActivityStarted, enrich_customer_data_no_agg
# ActivityStarted, enrich
# Target paths: ['/year=2014/month=12/']
# Looking for parquet files...
# Reading them into Pandas dataframe...
# Reading ISDWeather/year=2014/month=12/part-00004-tid-9219175779481662582-3729dfdb-ab32-4767-b9b6-11d2d644c3ce-83.c000.snappy.parquet under container isdweatherdatacontainer
# Done.
# ActivityCompleted: Activity=enrich, HowEnded=Success, Duration=41111.37 [ms]
# ActivityCompleted: Activity=enrich_customer_data_no_agg, HowEnded=Success, Duration=41203.44 [ms]
# ActivityStarted, get_enricher
# ActivityCompleted: Activity=get_enricher, HowEnded=Success, Duration=17.96 [ms]
# ActivityStarted, enrich_customer_data_no_agg
# ActivityStarted, enrich
# Target paths: ['/year=2015/month=1/']
# Looking for parquet files...
# Reading them into Pandas dataframe...
# Reading ISDWeather/year=2015/month=1/part-00006-tid-2198075741767757560-e3eb994e-d560-4dfc-941e-0aae74c8d9ed-98.c000.snappy.parquet under container isdweatherdatacontainer
# Done.
# ActivityCompleted: Activity=enrich, HowEnded=Success, Duration=43527.36 [ms]
# ActivityCompleted: Activity=enrich_customer_data_no_agg, HowEnded=Success, Duration=43580.11 [ms]
# ActivityStarted, get_enricher
# ActivityCompleted: Activity=get_enricher, HowEnded=Success, Duration=19.69 [ms]
# ActivityStarted, enrich_customer_data_no_agg
# ActivityStarted, enrich
# Target paths: ['/year=2015/month=2/']
# Looking for parquet files...
# Reading them into Pandas dataframe...
# Reading ISDWeather/year=2015/month=2/part-00010-tid-2198075741767757560-e3eb994e-d560-4dfc-941e-0aae74c8d9ed-102.c000.snappy.parquet under container isdweatherdatacontainer
# Done.
# ActivityCompleted: Activity=enrich, HowEnded=Success, Duration=39870.61 [ms]
# ActivityCompleted: Activity=enrich_customer_data_no_agg, HowEnded=Success, Duration=39917.0 [ms]
# ActivityStarted, get_enricher
# ActivityCompleted: Activity=get_enricher, HowEnded=Success, Duration=20.74 [ms]
# ActivityStarted, enrich_customer_data_no_agg
# ActivityStarted, enrich
# Target paths: ['/year=2015/month=3/']
# Looking for parquet files...
# Reading them into Pandas dataframe...
# Reading ISDWeather/year=2015/month=3/part-00005-tid-2198075741767757560-e3eb994e-d560-4dfc-941e-0aae74c8d9ed-97.c000.snappy.parquet under container isdweatherdatacontainer
# Done.
# ActivityCompleted: Activity=enrich, HowEnded=Success, Duration=44280.98 [ms]
# ActivityCompleted: Activity=enrich_customer_data_no_agg, HowEnded=Success, Duration=44339.07 [ms]
# ActivityStarted, get_enricher
# ActivityCompleted: Activity=get_enricher, HowEnded=Success, Duration=17.61 [ms]
# ActivityStarted, enrich_customer_data_no_agg
# ActivityStarted, enrich
# Target paths: ['/year=2015/month=4/']
# Looking for parquet files...
# Reading them into Pandas dataframe...
# Reading ISDWeather/year=2015/month=4/part-00011-tid-2198075741767757560-e3eb994e-d560-4dfc-941e-0aae74c8d9ed-103.c000.snappy.parquet under container isdweatherdatacontainer
# Done.
# ActivityCompleted: Activity=enrich, HowEnded=Success, Duration=43311.91 [ms]
# ActivityCompleted: Activity=enrich_customer_data_no_agg, HowEnded=Success, Duration=43347.73 [ms]
# ActivityStarted, get_enricher
# ActivityCompleted: Activity=get_enricher, HowEnded=Success, Duration=17.16 [ms]
# ActivityStarted, enrich_customer_data_no_agg
# ActivityStarted, enrich
# Target paths: ['/year=2015/month=5/']
# Looking for parquet files...
# Reading them into Pandas dataframe...
# Reading ISDWeather/year=2015/month=5/part-00001-tid-2198075741767757560-e3eb994e-d560-4dfc-941e-0aae74c8d9ed-93.c000.snappy.parquet under container isdweatherdatacontainer
# Done.
# ActivityCompleted: Activity=enrich, HowEnded=Success, Duration=42948.68 [ms]
# ActivityCompleted: Activity=enrich_customer_data_no_agg, HowEnded=Success, Duration=42999.33 [ms]
# ActivityStarted, get_enricher
# ActivityCompleted: Activity=get_enricher, HowEnded=Success, Duration=20.54 [ms]
# ActivityStarted, enrich_customer_data_no_agg
# ActivityStarted, enrich
# Target paths: ['/year=2015/month=6/']
# Looking for parquet files...
# Reading them into Pandas dataframe...
# Reading ISDWeather/year=2015/month=6/part-00008-tid-2198075741767757560-e3eb994e-d560-4dfc-941e-0aae74c8d9ed-100.c000.snappy.parquet under container isdweatherdatacontainer
# Done.
# ActivityCompleted: Activity=enrich, HowEnded=Success, Duration=40811.53 [ms]
# ActivityCompleted: Activity=enrich_customer_data_no_agg, HowEnded=Success, Duration=40867.21 [ms]
# ActivityStarted, get_enricher
# ActivityCompleted: Activity=get_enricher, HowEnded=Success, Duration=17.17 [ms]
# ActivityStarted, enrich_customer_data_no_agg
# ActivityStarted, enrich
# Target paths: ['/year=2015/month=7/']
# Looking for parquet files...
# Reading them into Pandas dataframe...
# Reading ISDWeather/year=2015/month=7/part-00004-tid-2198075741767757560-e3eb994e-d560-4dfc-941e-0aae74c8d9ed-96.c000.snappy.parquet under container isdweatherdatacontainer
# Done.
# ActivityCompleted: Activity=enrich, HowEnded=Success, Duration=43527.2 [ms]
# ActivityCompleted: Activity=enrich_customer_data_no_agg, HowEnded=Success, Duration=43582.72 [ms]
# ActivityStarted, get_enricher
# ActivityCompleted: Activity=get_enricher, HowEnded=Success, Duration=17.76 [ms]
# ActivityStarted, enrich_customer_data_no_agg
# ActivityStarted, enrich
# Target paths: ['/year=2015/month=8/']
# Looking for parquet files...
# Reading them into Pandas dataframe...
# Reading ISDWeather/year=2015/month=8/part-00007-tid-2198075741767757560-e3eb994e-d560-4dfc-941e-0aae74c8d9ed-99.c000.snappy.parquet under container isdweatherdatacontainer
# Done.
# ActivityCompleted: Activity=enrich, HowEnded=Success, Duration=43075.59 [ms]
# ActivityCompleted: Activity=enrich_customer_data_no_agg, HowEnded=Success, Duration=43126.87 [ms]
# ActivityStarted, get_enricher
# ActivityCompleted: Activity=get_enricher, HowEnded=Success, Duration=17.8 [ms]
# ActivityStarted, enrich_customer_data_no_agg
# ActivityStarted, enrich
# Target paths: ['/year=2015/month=9/']
# Looking for parquet files...
# Reading them into Pandas dataframe...
# Reading ISDWeather/year=2015/month=9/part-00009-tid-2198075741767757560-e3eb994e-d560-4dfc-941e-0aae74c8d9ed-101.c000.snappy.parquet under container isdweatherdatacontainer
# Done.
# ActivityCompleted: Activity=enrich, HowEnded=Success, Duration=41673.19 [ms]
# ActivityCompleted: Activity=enrich_customer_data_no_agg, HowEnded=Success, Duration=41722.83 [ms]
# ActivityStarted, get_enricher
# ActivityCompleted: Activity=get_enricher, HowEnded=Success, Duration=17.24 [ms]
# ActivityStarted, enrich_customer_data_no_agg
# ActivityStarted, enrich
# Target paths: ['/year=2015/month=10/']
# Looking for parquet files...
# Reading them into Pandas dataframe...
# Reading ISDWeather/year=2015/month=10/part-00002-tid-2198075741767757560-e3eb994e-d560-4dfc-941e-0aae74c8d9ed-94.c000.snappy.parquet under container isdweatherdatacontainer
# Done.
# ActivityCompleted: Activity=enrich, HowEnded=Success, Duration=42945.69 [ms]
# ActivityCompleted: Activity=enrich_customer_data_no_agg, HowEnded=Success, Duration=42996.68 [ms]
# ActivityStarted, get_enricher
# ActivityCompleted: Activity=get_enricher, HowEnded=Success, Duration=18.69 [ms]
# ActivityStarted, enrich_customer_data_no_agg
# ActivityStarted, enrich
# Target paths: ['/year=2015/month=11/']
# Looking for parquet files...
# Reading them into Pandas dataframe...
# Reading ISDWeather/year=2015/month=11/part-00003-tid-2198075741767757560-e3eb994e-d560-4dfc-941e-0aae74c8d9ed-95.c000.snappy.parquet under container isdweatherdatacontainer
# Done.
# ActivityCompleted: Activity=enrich, HowEnded=Success, Duration=43708.65 [ms]
# ActivityCompleted: Activity=enrich_customer_data_no_agg, HowEnded=Success, Duration=43754.12 [ms]
# ActivityStarted, get_enricher
# ActivityCompleted: Activity=get_enricher, HowEnded=Success, Duration=17.34 [ms]
# ActivityStarted, enrich_customer_data_no_agg
# ActivityStarted, enrich
# Target paths: ['/year=2015/month=12/']
# Looking for parquet files...
# Reading them into Pandas dataframe...
# Reading ISDWeather/year=2015/month=12/part-00000-tid-2198075741767757560-e3eb994e-d560-4dfc-941e-0aae74c8d9ed-92.c000.snappy.parquet under container isdweatherdatacontainer
# Done.
# ActivityCompleted: Activity=enrich, HowEnded=Success, Duration=60355.98 [ms]
# ActivityCompleted: Activity=enrich_customer_data_no_agg, HowEnded=Success, Duration=60447.26 [ms]
# ActivityStarted, get_enricher
# ActivityCompleted: Activity=get_enricher, HowEnded=Success, Duration=17.05 [ms]
# ActivityStarted, enrich_customer_data_no_agg
# ActivityStarted, enrich
# Target paths: ['/year=2016/month=1/']
# Looking for parquet files...
# Reading them into Pandas dataframe...
# Reading ISDWeather/year=2016/month=1/part-00005-tid-6700213360605767691-4491b75c-f137-489b-b5df-4204b9326fda-110.c000.snappy.parquet under container isdweatherdatacontainer
# Done.
# ActivityCompleted: Activity=enrich, HowEnded=Success, Duration=60960.86 [ms]
# ActivityCompleted: Activity=enrich_customer_data_no_agg, HowEnded=Success, Duration=61040.38 [ms]
# ActivityStarted, get_enricher
# ActivityCompleted: Activity=get_enricher, HowEnded=Success, Duration=17.98 [ms]
# ActivityStarted, enrich_customer_data_no_agg
# ActivityStarted, enrich
# Target paths: ['/year=2016/month=2/']
# Looking for parquet files...
# Reading them into Pandas dataframe...
# Reading ISDWeather/year=2016/month=2/part-00011-tid-6700213360605767691-4491b75c-f137-489b-b5df-4204b9326fda-116.c000.snappy.parquet under container isdweatherdatacontainer
# Done.
# ActivityCompleted: Activity=enrich, HowEnded=Success, Duration=43105.63 [ms]
# ActivityCompleted: Activity=enrich_customer_data_no_agg, HowEnded=Success, Duration=43189.44 [ms]
# ActivityStarted, get_enricher
# ActivityCompleted: Activity=get_enricher, HowEnded=Success, Duration=17.53 [ms]
# ActivityStarted, enrich_customer_data_no_agg
# ActivityStarted, enrich
# Target paths: ['/year=2016/month=3/']
# Looking for parquet files...
# Reading them into Pandas dataframe...
# Reading ISDWeather/year=2016/month=3/part-00004-tid-6700213360605767691-4491b75c-f137-489b-b5df-4204b9326fda-109.c000.snappy.parquet under container isdweatherdatacontainer
# Done.
# ActivityCompleted: Activity=enrich, HowEnded=Success, Duration=46416.04 [ms]
# ActivityCompleted: Activity=enrich_customer_data_no_agg, HowEnded=Success, Duration=46471.95 [ms]
# ActivityStarted, get_enricher
# ActivityCompleted: Activity=get_enricher, HowEnded=Success, Duration=17.41 [ms]
# ActivityStarted, enrich_customer_data_no_agg
# ActivityStarted, enrich
# Target paths: ['/year=2016/month=4/']
# Looking for parquet files...
# Reading them into Pandas dataframe...
# Reading ISDWeather/year=2016/month=4/part-00008-tid-6700213360605767691-4491b75c-f137-489b-b5df-4204b9326fda-113.c000.snappy.parquet under container isdweatherdatacontainer
# Done.
# ActivityCompleted: Activity=enrich, HowEnded=Success, Duration=43887.97 [ms]
# ActivityCompleted: Activity=enrich_customer_data_no_agg, HowEnded=Success, Duration=43966.98 [ms]
# ActivityStarted, get_enricher
# ActivityCompleted: Activity=get_enricher, HowEnded=Success, Duration=17.72 [ms]
# ActivityStarted, enrich_customer_data_no_agg
# ActivityStarted, enrich
# Target paths: ['/year=2016/month=5/']
# Looking for parquet files...
# Reading them into Pandas dataframe...
# Reading ISDWeather/year=2016/month=5/part-00006-tid-6700213360605767691-4491b75c-f137-489b-b5df-4204b9326fda-111.c000.snappy.parquet under container isdweatherdatacontainer
# Done.
# ActivityCompleted: Activity=enrich, HowEnded=Success, Duration=44077.01 [ms]
# ActivityCompleted: Activity=enrich_customer_data_no_agg, HowEnded=Success, Duration=44163.85 [ms]
# ActivityStarted, get_enricher
# ActivityCompleted: Activity=get_enricher, HowEnded=Success, Duration=17.48 [ms]
# ActivityStarted, enrich_customer_data_no_agg
# ActivityStarted, enrich
# Target paths: ['/year=2016/month=6/']
# Looking for parquet files...
# Reading them into Pandas dataframe...
# Reading ISDWeather/year=2016/month=6/part-00010-tid-6700213360605767691-4491b75c-f137-489b-b5df-4204b9326fda-115.c000.snappy.parquet under container isdweatherdatacontainer
# Done.
# ActivityCompleted: Activity=enrich, HowEnded=Success, Duration=41326.38 [ms]
# ActivityCompleted: Activity=enrich_customer_data_no_agg, HowEnded=Success, Duration=41374.81 [ms]
# ActivityStarted, get_enricher
# ActivityCompleted: Activity=get_enricher, HowEnded=Success, Duration=17.47 [ms]
# ActivityStarted, enrich_customer_data_no_agg
# ActivityStarted, enrich
# Target paths: ['/year=2016/month=7/']
# Looking for parquet files...
# Reading them into Pandas dataframe...
# Reading ISDWeather/year=2016/month=7/part-00003-tid-6700213360605767691-4491b75c-f137-489b-b5df-4204b9326fda-108.c000.snappy.parquet under container isdweatherdatacontainer
# Done.
# ActivityCompleted: Activity=enrich, HowEnded=Success, Duration=52732.89 [ms]
# ActivityCompleted: Activity=enrich_customer_data_no_agg, HowEnded=Success, Duration=52784.83 [ms]
# ActivityStarted, get_enricher
# ActivityCompleted: Activity=get_enricher, HowEnded=Success, Duration=17.63 [ms]
# ActivityStarted, enrich_customer_data_no_agg
# ActivityStarted, enrich
# Target paths: ['/year=2016/month=8/']
# Looking for parquet files...
# Reading them into Pandas dataframe...
# Reading ISDWeather/year=2016/month=8/part-00001-tid-6700213360605767691-4491b75c-f137-489b-b5df-4204b9326fda-106.c000.snappy.parquet under container isdweatherdatacontainer
# Done.
# ActivityCompleted: Activity=enrich, HowEnded=Success, Duration=44712.9 [ms]
# ActivityCompleted: Activity=enrich_customer_data_no_agg, HowEnded=Success, Duration=44768.49 [ms]
# ActivityStarted, get_enricher
# ActivityCompleted: Activity=get_enricher, HowEnded=Success, Duration=21.75 [ms]
# ActivityStarted, enrich_customer_data_no_agg
# ActivityStarted, enrich
# Target paths: ['/year=2016/month=9/']
# Looking for parquet files...
# Reading them into Pandas dataframe...
# Reading ISDWeather/year=2016/month=9/part-00007-tid-6700213360605767691-4491b75c-f137-489b-b5df-4204b9326fda-112.c000.snappy.parquet under container isdweatherdatacontainer
# Done.
# ActivityCompleted: Activity=enrich, HowEnded=Success, Duration=45721.92 [ms]
# ActivityCompleted: Activity=enrich_customer_data_no_agg, HowEnded=Success, Duration=45792.78 [ms]
# ActivityStarted, get_enricher
# ActivityCompleted: Activity=get_enricher, HowEnded=Success, Duration=17.39 [ms]
# ActivityStarted, enrich_customer_data_no_agg
# ActivityStarted, enrich
# Target paths: ['/year=2016/month=10/']
# Looking for parquet files...
# Reading them into Pandas dataframe...
# Reading ISDWeather/year=2016/month=10/part-00002-tid-6700213360605767691-4491b75c-f137-489b-b5df-4204b9326fda-107.c000.snappy.parquet under container isdweatherdatacontainer
# Done.
# ActivityCompleted: Activity=enrich, HowEnded=Success, Duration=48494.7 [ms]
# ActivityCompleted: Activity=enrich_customer_data_no_agg, HowEnded=Success, Duration=48549.09 [ms]
# ActivityStarted, get_enricher
# ActivityCompleted: Activity=get_enricher, HowEnded=Success, Duration=16.91 [ms]
# ActivityStarted, enrich_customer_data_no_agg
# ActivityStarted, enrich
# Target paths: ['/year=2016/month=11/']
# Looking for parquet files...
# Reading them into Pandas dataframe...
# Reading ISDWeather/year=2016/month=11/part-00009-tid-6700213360605767691-4491b75c-f137-489b-b5df-4204b9326fda-114.c000.snappy.parquet under container isdweatherdatacontainer
# Done.
# ActivityCompleted: Activity=enrich, HowEnded=Success, Duration=102567.37 [ms]
# ActivityCompleted: Activity=enrich_customer_data_no_agg, HowEnded=Success, Duration=102611.05 [ms]
# ActivityStarted, get_enricher
# ActivityCompleted: Activity=get_enricher, HowEnded=Success, Duration=17.52 [ms]
# ActivityStarted, enrich_customer_data_no_agg
# ActivityStarted, enrich
# Target paths: ['/year=2016/month=12/']
# Looking for parquet files...
# Reading them into Pandas dataframe...
# Reading ISDWeather/year=2016/month=12/part-00000-tid-6700213360605767691-4491b75c-f137-489b-b5df-4204b9326fda-105.c000.snappy.parquet under container isdweatherdatacontainer
# Done.
# ActivityCompleted: Activity=enrich, HowEnded=Success, Duration=122545.74 [ms]
# ActivityCompleted: Activity=enrich_customer_data_no_agg, HowEnded=Success, Duration=122593.63 [ms]
# ActivityStarted, get_enricher
# ActivityCompleted: Activity=get_enricher, HowEnded=Success, Duration=17.22 [ms]
# ActivityStarted, enrich_customer_data_no_agg
# ActivityStarted, enrich
# Target paths: ['/year=2017/month=1/']
# Looking for parquet files...
# Reading them into Pandas dataframe...
# Reading ISDWeather/year=2017/month=1/part-00001-tid-1321158002197267978-8e3eb092-4b7a-42de-97ee-e23297ed8955-119.c000.snappy.parquet under container isdweatherdatacontainer
# Done.
# ActivityCompleted: Activity=enrich, HowEnded=Success, Duration=47248.72 [ms]
# ActivityCompleted: Activity=enrich_customer_data_no_agg, HowEnded=Success, Duration=47308.75 [ms]
# ActivityStarted, get_enricher
# ActivityCompleted: Activity=get_enricher, HowEnded=Success, Duration=17.4 [ms]
# ActivityStarted, enrich_customer_data_no_agg
# ActivityStarted, enrich
# Target paths: ['/year=2017/month=2/']
# Looking for parquet files...
# Reading them into Pandas dataframe...
# Reading ISDWeather/year=2017/month=2/part-00011-tid-1321158002197267978-8e3eb092-4b7a-42de-97ee-e23297ed8955-129.c000.snappy.parquet under container isdweatherdatacontainer
# Done.
# ActivityCompleted: Activity=enrich, HowEnded=Success, Duration=44875.39 [ms]
# ActivityCompleted: Activity=enrich_customer_data_no_agg, HowEnded=Success, Duration=44932.98 [ms]
# ActivityStarted, get_enricher
# ActivityCompleted: Activity=get_enricher, HowEnded=Success, Duration=12.19 [ms]
# ActivityStarted, enrich_customer_data_no_agg
# ActivityStarted, enrich
# Target paths: ['/year=2017/month=3/']
# Looking for parquet files...
# Reading them into Pandas dataframe...
# Reading ISDWeather/year=2017/month=3/part-00000-tid-1321158002197267978-8e3eb092-4b7a-42de-97ee-e23297ed8955-118.c000.snappy.parquet under container isdweatherdatacontainer
# Done.
# ActivityCompleted: Activity=enrich, HowEnded=Success, Duration=43882.2 [ms]
# ActivityCompleted: Activity=enrich_customer_data_no_agg, HowEnded=Success, Duration=43949.11 [ms]
# ActivityStarted, get_enricher
# ActivityCompleted: Activity=get_enricher, HowEnded=Success, Duration=17.48 [ms]
# ActivityStarted, enrich_customer_data_no_agg
# ActivityStarted, enrich
# Target paths: ['/year=2017/month=4/']
# Looking for parquet files...
# Reading them into Pandas dataframe...
# Reading ISDWeather/year=2017/month=4/part-00007-tid-1321158002197267978-8e3eb092-4b7a-42de-97ee-e23297ed8955-125.c000.snappy.parquet under container isdweatherdatacontainer
# Done.
# ActivityCompleted: Activity=enrich, HowEnded=Success, Duration=53383.3 [ms]
# ActivityCompleted: Activity=enrich_customer_data_no_agg, HowEnded=Success, Duration=53444.65 [ms]
# ActivityStarted, get_enricher
# ActivityCompleted: Activity=get_enricher, HowEnded=Success, Duration=17.69 [ms]
# ActivityStarted, enrich_customer_data_no_agg
# ActivityStarted, enrich
# Target paths: ['/year=2017/month=5/']
# Looking for parquet files...
# Reading them into Pandas dataframe...
# Reading ISDWeather/year=2017/month=5/part-00002-tid-1321158002197267978-8e3eb092-4b7a-42de-97ee-e23297ed8955-120.c000.snappy.parquet under container isdweatherdatacontainer
# Done.
# ActivityCompleted: Activity=enrich, HowEnded=Success, Duration=45802.38 [ms]
# ActivityCompleted: Activity=enrich_customer_data_no_agg, HowEnded=Success, Duration=45874.65 [ms]
# ActivityStarted, get_enricher
# ActivityCompleted: Activity=get_enricher, HowEnded=Success, Duration=17.22 [ms]
# ActivityStarted, enrich_customer_data_no_agg
# ActivityStarted, enrich
# Target paths: ['/year=2017/month=6/']
# Looking for parquet files...
# Reading them into Pandas dataframe...
# Reading ISDWeather/year=2017/month=6/part-00010-tid-1321158002197267978-8e3eb092-4b7a-42de-97ee-e23297ed8955-128.c000.snappy.parquet under container isdweatherdatacontainer
# Done.
# ActivityCompleted: Activity=enrich, HowEnded=Success, Duration=47608.01 [ms]
# ActivityCompleted: Activity=enrich_customer_data_no_agg, HowEnded=Success, Duration=47667.03 [ms]
# ActivityStarted, get_enricher
# ActivityCompleted: Activity=get_enricher, HowEnded=Success, Duration=17.83 [ms]
# ActivityStarted, enrich_customer_data_no_agg
# ActivityStarted, enrich
# Target paths: ['/year=2017/month=7/']
# Looking for parquet files...
# Reading them into Pandas dataframe...
# Reading ISDWeather/year=2017/month=7/part-00006-tid-1321158002197267978-8e3eb092-4b7a-42de-97ee-e23297ed8955-124.c000.snappy.parquet under container isdweatherdatacontainer
# Done.
# ActivityCompleted: Activity=enrich, HowEnded=Success, Duration=54551.39 [ms]
# ActivityCompleted: Activity=enrich_customer_data_no_agg, HowEnded=Success, Duration=54612.86 [ms]
# ActivityStarted, get_enricher
# ActivityCompleted: Activity=get_enricher, HowEnded=Success, Duration=19.39 [ms]
# ActivityStarted, enrich_customer_data_no_agg
# ActivityStarted, enrich
# Target paths: ['/year=2017/month=8/']
# Looking for parquet files...
# Reading them into Pandas dataframe...
# Reading ISDWeather/year=2017/month=8/part-00003-tid-1321158002197267978-8e3eb092-4b7a-42de-97ee-e23297ed8955-121.c000.snappy.parquet under container isdweatherdatacontainer
# Done.
# ActivityCompleted: Activity=enrich, HowEnded=Success, Duration=39574.97 [ms]
# ActivityCompleted: Activity=enrich_customer_data_no_agg, HowEnded=Success, Duration=39606.91 [ms]
# [2019-04-29 10:13:28.810135] End enriching...

# %% [markdown]
# ### The final result has been saved to ``"./nyc_energy_enriched.csv"``

# %%
all.head(5)
# Out:
#              timeStamp  demand     lat    long        new_datetime  \
# 0  2012-01-01 00:00:00  4937.5  40.701 -74.009 2012-01-01 00:00:00
# 1  2012-01-01 01:00:00  4752.1  40.701 -74.009 2012-01-01 01:00:00
# 2  2012-01-01 02:00:00  4542.6  40.701 -74.009 2012-01-01 02:00:00
# 3  2012-01-01 03:00:00  4357.7  40.701 -74.009 2012-01-01 03:00:00
# 4  2012-01-01 04:00:00  4275.5  40.701 -74.009 2012-01-01 04:00:00
#
#    temperature  precipTime  precipDepth  snowDepth  precipDepth/precipTime
# 0     7.665934        24.0         58.0        0.0                0.046384
# 1     7.665934        24.0         58.0        0.0                0.046384
# 2     7.665934        24.0         58.0        0.0                0.046384
# 3     7.665934        24.0         58.0        0.0                0.046384
# 4     7.665934        24.0         58.0        0.0                0.046384

# %% [markdown]
# <font color='blue'>The join success rate is 100%</font>

# %%
all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 49205 entries, 0 to 270
# Data columns (total 10 columns):
# timeStamp                 49205 non-null object
# demand                    49124 non-null float64
# lat                       49205 non-null float64
# long                      49205 non-null float64
# new_datetime              49205 non-null datetime64[ns]
# temperature               49205 non-null float64
# precipTime                49205 non-null float64
# precipDepth               49205 non-null float64
# snowDepth                 49205 non-null float64
# precipDepth/precipTime    49205 non-null float64
# dtypes: datetime64[ns](1), float64(8), object(1)
# memory usage: 4.1+ MB

# %%
all.describe()
# Out:
#              demand           lat       long   temperature  precipTime  \
# count  49124.000000  4.920500e+04  49205.000  49205.000000     49205.0
# mean    6067.447361  4.070100e+01    -74.009     13.372627        24.0
# std     1285.607657  7.105500e-15      0.000      9.640060         0.0
# min     2859.600000  4.070100e+01    -74.009    -13.226429        24.0
# 25%     5133.862250  4.070100e+01    -74.009      5.637931        24.0
# 50%     6020.071000  4.070100e+01    -74.009     13.955882        24.0
# 75%     6684.300000  4.070100e+01    -74.009     22.236709        24.0
# max    11456.000000  4.070100e+01    -74.009     32.852857        24.0
#
#         precipDepth     snowDepth  precipDepth/precipTime
# count  49205.000000  49205.000000            49205.000000
# mean     391.145534      1.072569               19.859086
# std     1042.909500      4.329940               61.989804
# min        0.000000      0.000000                0.000000
# 25%        0.000000      0.000000                0.000000
# 50%       10.000000      0.000000                0.065359
# 75%      135.000000      0.000000                2.711580
# max     7630.000000     51.228571              578.402778

# %%
report_joined[datetime(2016, 10, 1, 0, 0)]
# Out:
#             demand           lat     long  temperature  precipTime  \
# count   743.000000  7.440000e+02  744.000   744.000000       744.0
# mean   5427.314386  4.070100e+01  -74.009    15.386461        24.0
# std     880.418908  7.110207e-15    0.000     4.159070         0.0
# min    3946.383000  4.070100e+01  -74.009     7.381250        24.0
# 25%    4660.270500  4.070100e+01  -74.009    12.365179        24.0
# 50%    5433.483000  4.070100e+01  -74.009    15.759633        24.0
# 75%    6101.083000  4.070100e+01  -74.009    18.396000        24.0
# max    7853.300000  4.070100e+01  -74.009    24.327826        24.0
#
#        precipDepth  snowDepth  precipDepth/precipTime
# count   744.000000      744.0              744.000000
# mean     81.774194        0.0                1.889804
# std     138.531590        0.0                3.683908
# min       0.000000        0.0                0.000000
# 25%       0.000000        0.0                0.000000
# 50%       0.000000        0.0                0.000000
# 75%     140.000000        0.0                1.198718
# max     521.000000        0.0               13.738443

# %%
report_joined[datetime(2016, 11, 1, 0, 0)]
# Out:
#             demand           lat     long  temperature  precipTime  \
# count   720.000000  7.200000e+02  720.000   720.000000       720.0
# mean   5371.189944  4.070100e+01  -74.009    10.440883        24.0
# std     783.680586  7.110367e-15    0.000     3.318841         0.0
# min    3999.292000  4.070100e+01  -74.009     4.346117        24.0
# 25%    4622.829500  4.070100e+01  -74.009     7.377561        24.0
# 50%    5419.716500  4.070100e+01  -74.009    11.029123        24.0
# 75%    6115.795750  4.070100e+01  -74.009    12.923214        24.0
# max    6797.308000  4.070100e+01  -74.009    18.216071        24.0
#
#        precipDepth  snowDepth  precipDepth/precipTime
# count   720.000000      720.0              720.000000
# mean   1787.366667        0.0              130.880351
# std    1170.974488        0.0              122.276823
# min       0.000000        0.0                0.000000
# 25%       0.000000        0.0                0.000000
# 50%    2540.000000        0.0               78.905303
# 75%    2553.000000        0.0              232.143362
# max    2646.000000        0.0              404.605201

# %%
# EOF
