# %% [markdown]
# Copyright (c) Microsoft Corporation. All rights reserved.
#
# Licensed under the MIT License.

# %% [markdown]
# # Tutorial: Load demo data and enrich it with NOAA ISD Weather data.
#
# In this tutorial, you load the demo data (a parquet file in Azure Blob), check the data schema, enrich it with NOAA ISD Weather data.
#
# Prerequisites:
# > You must install the PyPI package on the cluster:
# > * azureml-contrib-opendatasets --index-url https://azuremlsdktestpypi.azureedge.net/sdk-release/Candidate/604C89A437BA41BD942B4F46D9A3591D
#
# Learn how to:
# > * Load the demo data from Azure Blob
# > * Check the demo data schema
# > * Initialize NoaaIsdWeather class to load weather data
# > * Enrich the demo data with weather data
# > * Display the joined result annd stats

# %% [markdown]
# ## Load demo parquet file from Azure Blob

# %%
from azure.storage.blob import BlockBlobService
from pyspark.sql import SparkSession

spark = SparkSession.builder.getOrCreate()

container_name = 'tutorials'
account_name = 'azureopendatastorage'
relative_path = 'noaa_isd_weather/demo.parquet'
df = spark.read.parquet('wasbs://%s@%s.blob.core.windows.net/%s' % (
    container_name,
    account_name,
    relative_path))
df.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">3</span><span class="ansired">]: </span>1850
# </div>

# %% [markdown]
# # Display the demo data

# %%
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>datetime</th><th>lat</th><th>long</th><th>stations.city</th><th>count</th><th>stations.dock_count</th></tr></thead><tbody><tr><td>2015-05-01T00:00:00.000+0000</td><td>37.787152</td><td>-122.38801299999999</td><td>San Francisco</td><td>28</td><td>15</td></tr><tr><td>2015-05-02T00:00:00.000+0000</td><td>37.787152</td><td>-122.38801299999999</td><td>San Francisco</td><td>5</td><td>15</td></tr><tr><td>2015-05-03T00:00:00.000+0000</td><td>37.787152</td><td>-122.38801299999999</td><td>San Francisco</td><td>11</td><td>15</td></tr><tr><td>2015-05-04T00:00:00.000+0000</td><td>37.787152</td><td>-122.38801299999999</td><td>San Francisco</td><td>24</td><td>15</td></tr><tr><td>2015-05-05T00:00:00.000+0000</td><td>37.787152</td><td>-122.38801299999999</td><td>San Francisco</td><td>24</td><td>15</td></tr><tr><td>2015-05-06T00:00:00.000+0000</td><td>37.787152</td><td>-122.38801299999999</td><td>San Francisco</td><td>28</td><td>15</td></tr><tr><td>2015-05-07T00:00:00.000+0000</td><td>37.787152</td><td>-122.38801299999999</td><td>San Francisco</td><td>20</td><td>15</td></tr><tr><td>2015-05-08T00:00:00.000+0000</td><td>37.787152</td><td>-122.38801299999999</td><td>San Francisco</td><td>21</td><td>15</td></tr><tr><td>2015-05-09T00:00:00.000+0000</td><td>37.787152</td><td>-122.38801299999999</td><td>San Francisco</td><td>9</td><td>15</td></tr><tr><td>2015-05-10T00:00:00.000+0000</td><td>37.787152</td><td>-122.38801299999999</td><td>San Francisco</td><td>10</td><td>15</td></tr><tr><td>2015-05-
from azureml.contrib.opendatasets.accessories.location_time_customer_data import LocationTimeCustomerData
from azureml.contrib.opendatasets import NoaaIsdWeather


_customer_data = LocationTimeCustomerData(df, LatLongColumn('lat', 'long'), 'datetime')
weather = NoaaIsdWeather(cols=["temperature", "windSpeed", "seaLvlPressure"])
weather_enricher = weather.get_enricher()
joined_data = weather_enricher.enrich_customer_data_with_agg(
  customer_data_object=_customer_data,
  location_match_granularity=5,
  time_round_granularity='day',
  agg='avg')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">ActivityStarted, get_enricher
# ActivityCompleted: Activity=get_enricher, HowEnded=Success, Duration=2.77 [ms]
# ActivityStarted, enrich_customer_data_with_agg
# ActivityStarted, enrich
# ActivityCompleted: Activity=enrich, HowEnded=Success, Duration=106634.5 [ms]
# ActivityCompleted: Activity=enrich_customer_data_with_agg, HowEnded=Success, Duration=106635.91 [ms]
# </div>

# %% [markdown]
# # Display the joined result

# %%
display(joined_data.data)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>lat</th><th>long</th><th>datetime</th><th>stations.city</th><th>count</th><th>stations.dock_count</th><th>row_id</th><th>avg(temperature)</th><th>avg(windSpeed)</th><th>avg(seaLvlPressure)</th></tr></thead><tbody><tr><td>37.330165</td><td>-121.88583100000001</td><td>2015-05-27T00:00:00.000+0000</td><td>San Jose</td><td>2</td><td>15</td><td>555</td><td>17.041747572815535</td><td>4.40576923076923</td><td>1016.0708333333332</td></tr><tr><td>37.389218</td><td>-122.081896</td><td>2015-05-24T00:00:00.000+0000</td><td>Mountain View</td><td>1</td><td>15</td><td>607</td><td>14.564999999999998</td><td>3.620833333333334</td><td>1016.9791666666666</td></tr><tr><td>37.444521</td><td>-122.16309299999999</td><td>2015-05-27T00:00:00.000+0000</td><td>Palo Alto</td><td>1</td><td>11</td><td>1848</td><td>14.850344827586207</td><td>3.705442176870746</td><td>1016.3666666666668</td></tr><tr><td>37.781039</td><td>-122.411748</td><td>2015-05-21T00:00:00.000+0000</td><td>San Francisco</td><td>38</td><td>23</td><td>1569</td><td>13.967088607594935</td><td>3.2710638297872303</td><td>1014.4471153846152</td></tr><tr><td>37.791464000000005</td><td>-122.391034</td><td>2015-05-23T00:00:00.000+0000</td><td>San Francisco</td><td>9</td><td>19</td><td>496</td><td>13.847904191616768</td><td>4.9656976744186005</td><td>1018.7134615384616</td></tr><tr><td>37.794139</td><td>-122.394434</td><td>2015-05-14T00:00:00.000+0000</td><td>San Francisco</td><td>50</td><td>23</td><td>430</td><td>14.23948717948718</td><td>3.145641025641024</td><td>1011.5009615384613</td></tr><tr><td>37.795392</td><td>-122.394203</td><td>2015-05-24T00:00:00.000+0000</td><td>San Francisco</td><td>30</td><td>23</td><td>1264</td><td>13.388111888111888</td><td>4.8027972027971995</td><td>1017.2605769230772</td></tr><tr><td>37.795392</td><td>-122.394203</td><td>2015-05-31T00:00:00.000+0000</td><td>San Francisco</td><td>13</td><td>23</td><td>1271</td><td>13.20612244897959</td><td>4.1484693877551</td><td>1013.8009615384617</td></tr><tr><td>37.337391</td><td>-121.886995</td><td>2015-05-24T00:00:00.000+0000</td><td>San Jose</td><td>5</td><td>15</td><td>1800</td><td>16.338297872340423</td><td>3.8212765957446813</td><td>1016.9791666666666</td></tr><tr><td>37.348742</td><td>-121.89471499999999</td><td>2015-05-26T00:00:00.000+0000</td><td>San Jose</td><td>5</td><td>15</td><td>581</td><td>16.492473118279573</td><td>4.138709677419354</td><td>1015.5375</td></tr><tr><td>37.771058000000004</td><td>-122.402717</td><td>2015-05-07T00:00:00.000+0000</td><td>San Francisco</td><td>59</td><td>15</td><td>193</td><td>12.235869565217392</td><td>4.744021739130437</td><td>1008.8201923076924</td></tr><tr><td>37.789625</td><td>-122.400811</td><td>2015-05-17T00:00:00.000+0000</td><td>San Francisco</td><td>3</td><td>27</td><td>1148</td><td>13.281283422459895</td><td>4.3575268817204265</td><td>1017.1903846153845</td></tr><tr><td>37.389218</td><td>-122.081896</td><td>2015-05-03T00:00:00.000+0000</td><td>Mountain View</td><td>2</td><td>15</td><td>588</td><td>15.32087912087912</td><td>3.834146341463414</td><td>1011.7937500000002</td></tr><tr><td>37.486078000000006</td><td>-122.23208899999999</td><td>2015-05-19T00:00:00.000+0000</td><td>Redwood City</td><td>7</td><td>25</td><td>278</td><td>14.158620689655173</td><td>3.0779310344827566</td><td>1019.7416666666667</td></tr><tr><td>37.776617</td><td>-122.39526000000001</td><td>2015-05-21T00:00:00.000+0000</td><td>San Francisco</td><td>99</td><td>19</td><td>1772</td><td>13.967088607594935</td><td>3.2710638297872303</td><td>1014.4471153846152</td></tr><tr><td>37.77865</td><td>-122.41823500000001</td><td>2015-05-25T00:00:00.000+0000</td><td>San Francisco</td><td>1</td><td>19</td><td>1513</td><td>13.368939393939398</td><td>4.843939393939391</td><td>1015.4509615384613</td></tr><tr><td>37.784878000000006</td><td>-122.40101399999999</td><td>2015-05-13T00:00:00.000+0000</td><td>San  ...

# %% [markdown]
# # Convert the joined spark dataframe to pandas dataframe

# %%
joined_data_pandas = joined_data.data.toPandas()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# # Check the stats of joined result

# %%
joined_data_pandas.info()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">&lt;class &apos;pandas.core.frame.DataFrame&apos;&gt;
# RangeIndex: 1850 entries, 0 to 1849
# Data columns (total 10 columns):
# lat                    1850 non-null float64
# long                   1850 non-null float64
# datetime               1850 non-null datetime64[ns]
# stations.city          1850 non-null object
# count                  1850 non-null int32
# stations.dock_count    1850 non-null int32
# row_id                 1850 non-null int64
# avg(temperature)       1850 non-null float64
# avg(windSpeed)         1850 non-null float64
# avg(seaLvlPressure)    1850 non-null float64
# dtypes: datetime64[ns](1), float64(5), int32(2), int64(1), object(1)
# memory usage: 130.2+ KB
# </div>
